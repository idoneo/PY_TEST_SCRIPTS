# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
mth161 = pd.read_excel('C:/Users/mjc341/desktop/TESTPY/MTH161.xlsx')

# %%
mth161.head(5)
# Out:
#      APP_ID  ALEKS AP  IB COURSE Credit  ACT MTH  SAT-MSS (NEW)  SAT_MTH (NEW)
# 0  50432885     89  0   0             0        0              0              0
# 1  50457667     84  0   0             0        0              0              0
# 2  50475188      0  0   0       MTH 101        0              0            600
# 3  50480064     63  0   0             0        0              0              0
# 4  50480105     65  0   0       MTH 101        0              0              0

# %%
mth161.dtypes
# Out:
# APP_ID            int64
# ALEKS             int64
# AP               object
# IB                int64
# COURSE Credit    object
# ACT MTH           int64
# SAT-MSS (NEW)     int64
# SAT_MTH (NEW)     int64
# dtype: object

# %%
mth161.columns
# Out:
# Index(['APP_ID', 'ALEKS', 'AP', 'IB', 'COURSE Credit', 'ACT MTH',
#        'SAT-MSS (NEW)', 'SAT_MTH (NEW)'],
#       dtype='object')

# %%
mth161.rename (columns= {'APP_ID':'ID', 'ALEKS':'ALKS', 'COURSE Credit':'COURSE', 'ACT MTH':'ACT',
       'SAT-MSS (NEW)':'MSS', 'SAT_MTH (NEW)':'MTH'})
# Out:
#             ID  ALKS     AP  IB   COURSE  ACT  MSS  MTH
# 0     50432885    89      0   0        0    0    0    0
# 1     50457667    84      0   0        0    0    0    0
# 2     50475188     0      0   0  MTH 101    0    0  600
# 3     50480064    63      0   0        0    0    0    0
# 4     50480105    65      0   0  MTH 101    0    0    0
# 5     50480115    73      0   0        0    0    0    0
# 6     50480127    65      0   0        0    0    0    0
# 7     54000209    81      0   0        0    0    0    0
# 8     54000751    90  MAB 5   0        0    0    0    0
# 9     53673491    55      0   0        0    0    0    0
# 10    54001161    67      0   0        0    0    0    0
# 11    54005970    87      0   0  MTH 101    0    0    0
# 12    53762062    79      0   0        0    0    0    0
# 13    54006062    81      0   0        0    0    0    0
# 14    54006147    81      0   0        0    0    0    0
# 15    54006778    84      0   0        0    0    0    0
# ...

# %%
MTH_LEVEL = []

# %%
for row in mth161['ALEKS']:
    if row >55:
        MTH_LEVEL.append ('yes')
    else:
        MTH_LEVEL.append('no')

# %%
mth161.head(10)
# Out:
#      APP_ID  ALEKS     AP  IB COURSE Credit  ACT MTH  SAT-MSS (NEW)  \
# 0  50432885     89      0   0             0        0              0
# 1  50457667     84      0   0             0        0              0
# 2  50475188      0      0   0       MTH 101        0              0
# 3  50480064     63      0   0             0        0              0
# 4  50480105     65      0   0       MTH 101        0              0
# 5  50480115     73      0   0             0        0              0
# 6  50480127     65      0   0             0        0              0
# 7  54000209     81      0   0             0        0              0
# 8  54000751     90  MAB 5   0             0        0              0
# 9  53673491     55      0   0             0        0              0
#
#    SAT_MTH (NEW)
# 0              0
# 1              0
# 2            600
# 3              0
# 4              0
# 5              0
# 6              0
# 7              0
# 8              0
# 9              0

# %%
mth161['MTH_LEVEL'] = MTH_LEVEL

# %%
mth161.head(10)
# Out:
#      APP_ID  ALEKS     AP  IB COURSE Credit  ACT MTH  SAT-MSS (NEW)  \
# 0  50432885     89      0   0             0        0              0
# 1  50457667     84      0   0             0        0              0
# 2  50475188      0      0   0       MTH 101        0              0
# 3  50480064     63      0   0             0        0              0
# 4  50480105     65      0   0       MTH 101        0              0
# 5  50480115     73      0   0             0        0              0
# 6  50480127     65      0   0             0        0              0
# 7  54000209     81      0   0             0        0              0
# 8  54000751     90  MAB 5   0             0        0              0
# 9  53673491     55      0   0             0        0              0
#
#    SAT_MTH (NEW) MTH_LEVEL
# 0              0       yes
# 1              0       yes
# 2            600        no
# 3              0       yes
# 4              0       yes
# 5              0       yes
# ...

# %%
mth161=mth161.rename (columns= {'APP_ID':'ID', 'ALEKS':'ALKS', 'COURSE Credit':'COURSE', 'ACT MTH':'ACT',
       'SAT-MSS (NEW)':'MSS', 'SAT_MTH (NEW)':'MTH'})

# %%
mth161.head(4)
# Out:
#          ID  ALKS AP  IB   COURSE  ACT  MSS  MTH MTH_LEVEL
# 0  50432885    89  0   0        0    0    0    0       yes
# 1  50457667    84  0   0        0    0    0    0       yes
# 2  50475188     0  0   0  MTH 101    0    0  600        no
# 3  50480064    63  0   0        0    0    0    0       yes

# %%
for row in mth161['ALKS']:
    if row >55:
        MTH_LEVEL.append ('yes')
    else:
        MTH_LEVEL.append('no')

# %%
len('ALKS')
# Out:
# 4

# %%
len('MTH_LEVEL')
# Out:
# 9

# %%
len(mth161['ALKS'])
# Out:
# 1791

# %%
len(mth161['MTH_LEVEL'])
# Out:
# 1791

# %%
del (mth161['MTH_LEVEL'])

# %%
mth161.head(2)
# Out:
#          ID  ALKS AP  IB COURSE  ACT  MSS  MTH
# 0  50432885    89  0   0      0    0    0    0
# 1  50457667    84  0   0      0    0    0    0

# %%
for row in mth161['ALKS']:
    if row <55:
        MTH_LEVEL.append ('Algebra')
    elif row >=55:
        MTH_LEVEL.append('pre-calc')
    elif row >=65:
        MTH_LEVEL.append ('pre-calc 130,108,140')
    elif row >=75:
        MTH_LEVEL.append('MTH161 ready')
    else:
        MTH_LEVEL.append('error')

# %%
len(MTH_LEVEL)
# Out:
# 5373

# %%
MTH_LEVEL
# Out:
# ['yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'yes',
#  'no',
#  'yes',
#  'no',
#  'yes',
#  'yes',
#  'yes',
# ...

# %%
ALEKS_MTH_LEVEL = []

# %%
for row in mth161['ALKS']:
    if row <55:
        ALEKS_MTH_LEVEL.append ('Algebra')
    elif row >=55:
        ALEKS_MTH_LEVEL.append('pre-calc')
    elif row >=65:
        ALEKS_MTH_LEVEL.append ('pre-calc 130,108,140')
    elif row >=75:
        ALEKS_MTH_LEVEL.append('MTH161 ready')
    else:
        ALEKS_MTH_LEVEL.append('error')

# %%
mth161['ALEKS_MTH_LEVEL'] = ALEKS_MTH_LEVEL

# %%
mth161.head(15)
# Out:
#           ID  ALKS     AP  IB   COURSE  ACT  MSS  MTH ALEKS_MTH_LEVEL
# 0   50432885    89      0   0        0    0    0    0        pre-calc
# 1   50457667    84      0   0        0    0    0    0        pre-calc
# 2   50475188     0      0   0  MTH 101    0    0  600         Algebra
# 3   50480064    63      0   0        0    0    0    0        pre-calc
# 4   50480105    65      0   0  MTH 101    0    0    0        pre-calc
# 5   50480115    73      0   0        0    0    0    0        pre-calc
# 6   50480127    65      0   0        0    0    0    0        pre-calc
# 7   54000209    81      0   0        0    0    0    0        pre-calc
# 8   54000751    90  MAB 5   0        0    0    0    0        pre-calc
# 9   53673491    55      0   0        0    0    0    0        pre-calc
# 10  54001161    67      0   0        0    0    0    0        pre-calc
# 11  54005970    87      0   0  MTH 101    0    0    0        pre-calc
# ...

# %%
for row in mth161['ALKS']:
    if row <55:
        MTH_LEVEL.append ('Algebra')
    elif row >=55 and row <65:
        MTH_LEVEL.append('pre-calc')
    elif row >=65 and row <75:
        MTH_LEVEL.append ('pre-calc 130,108,140')
    elif row >=75:
        MTH_LEVEL.append('MTH161 ready')
    else:
        MTH_LEVEL.append('error')

# %%
ALKS_MTH_LEVEL = []

# %%
for row in mth161['ALKS']:
    if row <55:
        ALKS_MTH_LEVEL.append ('Algebra')
    elif row >=55 and row <65:
        ALKS_MTH_LEVEL.append('pre-calc')
    elif row >=65 and row <75:
        ALKS_MTH_LEVEL.append ('pre-calc 130,108,140')
    elif row >=75:
        ALKS_MTH_LEVEL.append('MTH161 ready')
    else:
        ALKS_MTH_LEVEL.append('error')

# %%
len(ALKS_MTH_LEVEL)
# Out:
# 1791

# %%
ALKS_MTH_LEVEL
# Out:
# ['MTH161 ready',
#  'MTH161 ready',
#  'Algebra',
#  'pre-calc',
#  'pre-calc 130,108,140',
#  'pre-calc 130,108,140',
#  'pre-calc 130,108,140',
#  'MTH161 ready',
#  'MTH161 ready',
#  'pre-calc',
#  'pre-calc 130,108,140',
#  'MTH161 ready',
#  'MTH161 ready',
#  'MTH161 ready',
#  'MTH161 ready',
#  'MTH161 ready',
#  'pre-calc',
#  'pre-calc',
#  'MTH161 ready',
#  'MTH161 ready',
#  'Algebra',
#  'MTH161 ready',
#  'MTH161 ready',
#  'pre-calc 130,108,140',
#  'pre-calc',
#  'pre-calc 130,108,140',
#  'Algebra',
#  'pre-calc',
#  'MTH161 ready',
#  'MTH161 ready',
#  'pre-calc',
#  'MTH161 ready',
#  'Algebra',
#  'Algebra',
#  'pre-calc',
#  'MTH161 ready',
#  'MTH161 ready',
#  'Algebra',
#  'pre-calc 130,108,140',
#  'MTH161 ready',
#  'MTH161 ready',
#  'MTH161 ready',
#  'Algebra',
#  'MTH161 ready',
#  'pre-calc 130,108,140',
#  'pre-calc 130,108,140',
#  'MTH161 ready',
#  'MTH161 ready',
#  'MTH161 ready',
#  'pre-calc',
#  'pre-calc 130,108,140',
#  'pre-calc',
# ...

# %%
mth161['ALKS_MTH_LEVEL'] = ALKS_MTH_LEVEL

# %%
del mth161['ALEKS_MTH_LEVEL']
mth161.head(5)
# Out:
#          ID  ALKS AP  IB   COURSE  ACT  MSS  MTH        ALKS_MTH_LEVEL
# 0  50432885    89  0   0        0    0    0    0          MTH161 ready
# 1  50457667    84  0   0        0    0    0    0          MTH161 ready
# 2  50475188     0  0   0  MTH 101    0    0  600               Algebra
# 3  50480064    63  0   0        0    0    0    0              pre-calc
# 4  50480105    65  0   0  MTH 101    0    0    0  pre-calc 130,108,140

# %%
AP_MTH_LEVEL = []

# %%
for row in mth161['AP']:
    if row == "MAB 3":
        AP_MTH_LEVEL.append ('pre-calc 130,108,140')
    elif row == 'MAB 4 ' or row == 'MAB 5':
        AP_MTH_LEVEL.append ('MTH161 ready')
    elif row == 'MBC 4' or row == 'MBC 5' or row == 'MBC 6':
        AP_MTH_LEVEL.append ('MTH161 ready')
    else:
        AP_MTH_LEVEL.append('error')

# %%
len (AP_MTH_LEVEL)
# Out:
# 1791

# %%
mth161['AP_MTH_LEVEL'] = AP_MTH_LEVEL

# %%
mth161.head(5)
# Out:
#          ID  ALKS AP  IB   COURSE  ACT  MSS  MTH        ALKS_MTH_LEVEL  \
# 0  50432885    89  0   0        0    0    0    0          MTH161 ready
# 1  50457667    84  0   0        0    0    0    0          MTH161 ready
# 2  50475188     0  0   0  MTH 101    0    0  600               Algebra
# 3  50480064    63  0   0        0    0    0    0              pre-calc
# 4  50480105    65  0   0  MTH 101    0    0    0  pre-calc 130,108,140
#
#   AP_MTH_LEVEL
# 0        error
# 1        error
# 2        error
# 3        error
# 4        error

# %%
AP_MTH_LEVEL
# Out:
# ['error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'MTH161 ready',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'MTH161 ready',
#  'MTH161 ready',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'MTH161 ready',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'MTH161 ready',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
#  'error',
# ...

# %%
IB_MTH_LEVEL = []

# %%
for row in mth161['IB']:
    if row >= 4:
        IB_MTH_LEVEL.append ('MTH161 ready')
    else:
        IB_MTH_LEVEL.append('none')

# %%
len (IB_MTH_LEVEL)
# Out:
# 1791

# %%
mth161['IB_MTH_LEVEL'] = IB_MTH_LEVEL

# %%
ACT_MTH_LEVEL = []

# %%
for row in mth161['ACT']:
    if row <25:
        ACT_MTH_LEVEL.append ('Algebra')
    elif row >=25 and row <27:
        ACT_MTH_LEVEL.append('pre-calc')
    elif row >=28 and row <30:
        ACT_MTH_LEVEL.append ('pre-calc 130,108,140')
    elif row >=31:
        ACT_MTH_LEVEL.append('MTH161 ready')
    else:
         ACT_MTH_LEVEL.append('none')

# %%
len (ACT_MTH_LEVEL)
# Out:
# 1791

# %%
mth161['ACT_MTH_LEVEL'] = ACT_MTH_LEVEL

# %%
SAT_MSS_LEVEL = []

# %%
for row in mth161['ACT']:
    if row <600:
        SAT_MSS_LEVEL.append ('Algebra')
    elif row >=600 and row <640:
        SAT_MSS_LEVEL.append('pre-calc')
    elif row >=650 and row <720:
        SAT_MSS_LEVEL.append ('pre-calc 130,108,140')
    elif row >=730:
        SAT_MSS_LEVEL.append('MTH161 ready')
    else:
         SAT_MSS_LEVEL.append('none')

# %%
len (SAT_MSS_LEVEL)
# Out:
# 1791

# %%
mth161['SAT_MSS_LEVEL'] = SAT_MSS_LEVEL

# %%
mth161.head(5)
# Out:
#          ID  ALKS AP  IB   COURSE  ACT  MSS  MTH        ALKS_MTH_LEVEL  \
# 0  50432885    89  0   0        0    0    0    0          MTH161 ready
# 1  50457667    84  0   0        0    0    0    0          MTH161 ready
# 2  50475188     0  0   0  MTH 101    0    0  600               Algebra
# 3  50480064    63  0   0        0    0    0    0              pre-calc
# 4  50480105    65  0   0  MTH 101    0    0    0  pre-calc 130,108,140
#
#   AP_MTH_LEVEL IB_MTH_LEVEL ACT_MTH_LEVEL SAT_MSS_LEVEL
# 0        error         none       Algebra       Algebra
# 1        error         none       Algebra       Algebra
# 2        error         none       Algebra       Algebra
# 3        error         none       Algebra       Algebra
# 4        error         none       Algebra       Algebra

# %%
del mth161['AP_MTH_LEVEL']
del mth161['IB_MTH_LEVEL']
del mth161['ACT_MTH_LEVEL']
del mth161['SAT_MSS_LEVEL']

# %% [markdown]
# mth161.head(5)

# %%
mth161.head(5)
# Out:
#          ID  ALKS AP  IB   COURSE  ACT  MSS  MTH        ALKS_MTH_LEVEL
# 0  50432885    89  0   0        0    0    0    0          MTH161 ready
# 1  50457667    84  0   0        0    0    0    0          MTH161 ready
# 2  50475188     0  0   0  MTH 101    0    0  600               Algebra
# 3  50480064    63  0   0        0    0    0    0              pre-calc
# 4  50480105    65  0   0  MTH 101    0    0    0  pre-calc 130,108,140

# %%
ACT_LEVEL = []

# %%
for row in mth161['ACT']:
    if row <25:
        ACT_LEVEL.append ('Algebra')
    elif row >=25 and row <27:
        ACT_LEVEL.append('pre-calc')
    elif row >=28 and row <30:
        ACT_LEVEL.append ('pre-calc 130,108,140')
    elif row >=31:
        ACT_LEVEL.append('MTH161 ready')
    else:
         ACT_LEVEL.append('none')

# %% [markdown]
# mth161['ACT_LEVEL'] = ACT_LEVEL

# %%
mth161['ACT_LEVEL'] = ACT_LEVEL

# %%
mth161.head(5)
# Out:
#          ID  ALKS AP  IB   COURSE  ACT  MSS  MTH        ALKS_MTH_LEVEL  \
# 0  50432885    89  0   0        0    0    0    0          MTH161 ready
# 1  50457667    84  0   0        0    0    0    0          MTH161 ready
# 2  50475188     0  0   0  MTH 101    0    0  600               Algebra
# 3  50480064    63  0   0        0    0    0    0              pre-calc
# 4  50480105    65  0   0  MTH 101    0    0    0  pre-calc 130,108,140
#
#   ACT_LEVEL
# 0   Algebra
# 1   Algebra
# 2   Algebra
# 3   Algebra
# 4   Algebra

# %%
ACT_LEVEL
# Out:
# ['Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'Algebra',
#  'none',
#  'Algebra',
# ...

# %%
ACT2_LEVEL = []

# %%
for row in mth161['ACT']:
    if row >1 and row <25:
        ACT2_LEVEL.append ('Algebra')
    elif row >=25 and row <27:
        ACT2_LEVEL.append('pre-calc')
    elif row >=28 and row <30:
        ACT2_LEVEL.append ('pre-calc 130,108,140')
    elif row >=31:
        ACT2_LEVEL.append('MTH161 ready')
    else:
         ACT2_LEVEL.append('none')

# %%
mth161['ACT2_LEVEL'] = ACT2_LEVEL

# %%
mth161.head(14)
# Out:
#           ID  ALKS     AP  IB   COURSE  ACT  MSS  MTH        ALKS_MTH_LEVEL  \
# 0   50432885    89      0   0        0    0    0    0          MTH161 ready
# 1   50457667    84      0   0        0    0    0    0          MTH161 ready
# 2   50475188     0      0   0  MTH 101    0    0  600               Algebra
# 3   50480064    63      0   0        0    0    0    0              pre-calc
# 4   50480105    65      0   0  MTH 101    0    0    0  pre-calc 130,108,140
# 5   50480115    73      0   0        0    0    0    0  pre-calc 130,108,140
# 6   50480127    65      0   0        0    0    0    0  pre-calc 130,108,140
# 7   54000209    81      0   0        0    0    0    0          MTH161 ready
# 8   54000751    90  MAB 5   0        0    0    0    0          MTH161 ready
# 9   53673491    55      0   0        0    0    0    0              pre-calc
# 10  54001161    67      0   0        0    0    0    0  pre-calc 130,108,140
# ...

# %%
del mth161['ACT_LEVEL']

# %%
mth161.head(3)
# Out:
#          ID  ALKS AP  IB   COURSE  ACT  MSS  MTH ALKS_MTH_LEVEL ACT2_LEVEL
# 0  50432885    89  0   0        0    0    0    0   MTH161 ready       none
# 1  50457667    84  0   0        0    0    0    0   MTH161 ready       none
# 2  50475188     0  0   0  MTH 101    0    0  600        Algebra       none

# %%
CRSE_LEVEL = []

# %%
for row in mth161['COURSE']:
    if row == 'MTH 099':
        CRSE_LEVEL.append ('Algebra')
    elif row == 'MTH 101':
        CRSE_LEVEL.append('pre-calc')
    elif row == 'MTH 107' or row == 'MTH 105' or row == 'MTH 113':
        CRSE_LEVEL.append ('pre-calc 130,108,140')
    elif row == 'MTH 130' or row == 'MTH 108' or row == 'MTH 140':
        CRSE_LEVEL.append('MTH161 ready')
    else:
         CRSE_LEVEL.append('none')

# %%
mth161 ['CRSE_LEVEL'] = CRSE_LEVEL

# %%
mth161.head(5)
# Out:
#          ID  ALKS AP  IB   COURSE  ACT  MSS  MTH        ALKS_MTH_LEVEL  \
# 0  50432885    89  0   0        0    0    0    0          MTH161 ready
# 1  50457667    84  0   0        0    0    0    0          MTH161 ready
# 2  50475188     0  0   0  MTH 101    0    0  600               Algebra
# 3  50480064    63  0   0        0    0    0    0              pre-calc
# 4  50480105    65  0   0  MTH 101    0    0    0  pre-calc 130,108,140
#
#   ACT2_LEVEL CRSE_LEVEL
# 0       none       none
# 1       none       none
# 2       none   pre-calc
# 3       none       none
# 4       none   pre-calc

# %%
MSS_LEVEL = []

# %%
for row in mth161['MSS']:
    if row >0 and row < 600:
        MSS_LEVEL.append ('Algebra')
    elif row >= 600 and row < 640:
        MSS_LEVEL.append('pre-calc')
    elif row >= 650 and row <720:
        MSS_LEVEL.append ('pre-calc 130,108,140')
    elif row >= 730:
        MSS_LEVEL.append('MTH161 ready')
    else:
         MSS_LEVEL.append('none')

# %%
len (MSS_LEVEL)
# Out:
# 1791

# %%
mth161 ['MSS_LEVEL'] = MSS_LEVEL

# %%
mth161.head(4)
# Out:
#          ID  ALKS AP  IB   COURSE  ACT  MSS  MTH ALKS_MTH_LEVEL ACT2_LEVEL  \
# 0  50432885    89  0   0        0    0    0    0   MTH161 ready       none
# 1  50457667    84  0   0        0    0    0    0   MTH161 ready       none
# 2  50475188     0  0   0  MTH 101    0    0  600        Algebra       none
# 3  50480064    63  0   0        0    0    0    0       pre-calc       none
#
#   CRSE_LEVEL MSS_LEVEL
# 0       none      none
# 1       none      none
# 2   pre-calc      none
# 3       none      none

# %%
SATMTH_LEVEL = []

# %%
for row in mth161['MTH']:
    if row >0 and row < 580:
        SATMTH_LEVEL.append ('Algebra')
    elif row >= 580 and row < 620:
        SATMTH_LEVEL.append('pre-calc')
    elif row >= 630 and row <790:
        SATMTH_LEVEL.append ('pre-calc 130,108,140')
    elif row >= 700:
        SATMTH_LEVEL.append('MTH161 ready')
    else:
         SATMTH_LEVEL.append('none')

# %%
mth161 ['SATMTH_LEVEL'] = SATMTH_LEVEL

# %%
mth161.head(4)
# Out:
#          ID  ALKS AP  IB   COURSE  ACT  MSS  MTH ALKS_MTH_LEVEL ACT2_LEVEL  \
# 0  50432885    89  0   0        0    0    0    0   MTH161 ready       none
# 1  50457667    84  0   0        0    0    0    0   MTH161 ready       none
# 2  50475188     0  0   0  MTH 101    0    0  600        Algebra       none
# 3  50480064    63  0   0        0    0    0    0       pre-calc       none
#
#   CRSE_LEVEL MSS_LEVEL SATMTH_LEVEL
# 0       none      none         none
# 1       none      none         none
# 2   pre-calc      none     pre-calc
# 3       none      none         none

# %%
AP_LEVEL = []

# %%
for row in mth161['AP']:
    if row == "MAB 3":
        AP_LEVEL.append ('pre-calc 130,108,140')
    elif row == 'MAB 4 ' or row == 'MAB 5':
        AP_LEVEL.append ('MTH161 ready')
    elif row == 'MBC 4' or row == 'MBC 5' or row == 'MBC 6':
        AP_LEVEL.append ('MTH161 ready')
    else:
        AP_LEVEL.append('none')

# %%
IB_LEVEL = []

# %%
for row in mth161['IB']:
    if row >= 4:
        IB_LEVEL.append ('MTH161 ready')
    else:
        IB_LEVEL.append('none')

# %%
mth161['AP_LEVEL'] = AP_LEVEL
mth161['IB_LEVEL'] = IB_LEVEL

# %%
mth161.head(4)
# Out:
#          ID  ALKS AP  IB   COURSE  ACT  MSS  MTH ALKS_MTH_LEVEL ACT2_LEVEL  \
# 0  50432885    89  0   0        0    0    0    0   MTH161 ready       none
# 1  50457667    84  0   0        0    0    0    0   MTH161 ready       none
# 2  50475188     0  0   0  MTH 101    0    0  600        Algebra       none
# 3  50480064    63  0   0        0    0    0    0       pre-calc       none
#
#   CRSE_LEVEL MSS_LEVEL SATMTH_LEVEL AP_LEVEL IB_LEVEL
# 0       none      none         none     none     none
# 1       none      none         none     none     none
# 2   pre-calc      none     pre-calc     none     none
# 3       none      none         none     none     none

# %%
ALEK_MATH_LEVEL = []

# %%
for row in mth161['ALKS']:
    if row > 0 and row <55:
        ALEK_MATH_LEVEL.append ('Algebra')
    elif row >=55:
        ALEK_MATH_LEVEL.append('pre-calc')
    elif row >=65:
        ALEK_MATH_LEVEL.append ('pre-calc 130,108,140')
    elif row >=75:
        ALEK_MATH_LEVEL.append('MTH161 ready')
    else:
        ALEK_MATH_LEVEL.append('none')

# %%
mth161['ALEK_MATH_LEVEL'] =ALEK_MATH_LEVEL

# %%
del mth161['ALKS_MTH_LEVEL']

# %%
mth161.head(4)
# Out:
#          ID  ALKS AP  IB   COURSE  ACT  MSS  MTH ACT2_LEVEL CRSE_LEVEL  \
# 0  50432885    89  0   0        0    0    0    0       none       none
# 1  50457667    84  0   0        0    0    0    0       none       none
# 2  50475188     0  0   0  MTH 101    0    0  600       none   pre-calc
# 3  50480064    63  0   0        0    0    0    0       none       none
#
#   MSS_LEVEL SATMTH_LEVEL AP_LEVEL IB_LEVEL ALEK_MATH_LEVEL
# 0      none         none     none     none        pre-calc
# 1      none         none     none     none        pre-calc
# 2      none     pre-calc     none     none            none
# 3      none         none     none     none        pre-calc

# %%
 ALEK2_MATH_LEVEL = []

# %%
for row in mth161['ALKS']:
    if row > 0 and row <55:
        ALEK2_MATH_LEVEL.append ('Algebra')
    elif row >=55 and row <65:
        ALEK2_MATH_LEVEL.append('pre-calc')
    elif row >=65 and row < 75:
        ALEK2_MATH_LEVEL.append ('pre-calc 130,108,140')
    elif row >=75:
        ALEK2_MATH_LEVEL.append('MTH161 ready')
    else:
        ALEK2_MATH_LEVEL.append('none')

# %%
ALEK2_MATH_LEVEL
# Out:
# ['MTH161 ready',
#  'MTH161 ready',
#  'none',
#  'pre-calc',
#  'pre-calc 130,108,140',
#  'pre-calc 130,108,140',
#  'pre-calc 130,108,140',
#  'MTH161 ready',
#  'MTH161 ready',
#  'pre-calc',
#  'pre-calc 130,108,140',
#  'MTH161 ready',
#  'MTH161 ready',
#  'MTH161 ready',
#  'MTH161 ready',
#  'MTH161 ready',
#  'pre-calc',
#  'pre-calc',
#  'MTH161 ready',
#  'MTH161 ready',
#  'none',
#  'MTH161 ready',
#  'MTH161 ready',
#  'pre-calc 130,108,140',
#  'pre-calc',
#  'pre-calc 130,108,140',
#  'Algebra',
#  'pre-calc',
#  'MTH161 ready',
#  'MTH161 ready',
#  'pre-calc',
#  'MTH161 ready',
#  'none',
#  'none',
#  'pre-calc',
#  'MTH161 ready',
#  'MTH161 ready',
#  'none',
#  'pre-calc 130,108,140',
#  'MTH161 ready',
#  'MTH161 ready',
#  'MTH161 ready',
#  'Algebra',
#  'MTH161 ready',
#  'pre-calc 130,108,140',
#  'pre-calc 130,108,140',
#  'MTH161 ready',
#  'MTH161 ready',
#  'MTH161 ready',
#  'pre-calc',
#  'pre-calc 130,108,140',
#  'pre-calc',
# ...

# %%
del mth161['ALEK_MATH_LEVEL']

# %%
mth161['ALEK2_MATH_LEVEL'] = ALEK2_MATH_LEVEL

# %%
mth161.head(4)
# Out:
#          ID  ALKS AP  IB   COURSE  ACT  MSS  MTH ACT2_LEVEL CRSE_LEVEL  \
# 0  50432885    89  0   0        0    0    0    0       none       none
# 1  50457667    84  0   0        0    0    0    0       none       none
# 2  50475188     0  0   0  MTH 101    0    0  600       none   pre-calc
# 3  50480064    63  0   0        0    0    0    0       none       none
#
#   MSS_LEVEL SATMTH_LEVEL AP_LEVEL IB_LEVEL ALEK2_MATH_LEVEL
# 0      none         none     none     none     MTH161 ready
# 1      none         none     none     none     MTH161 ready
# 2      none     pre-calc     none     none             none
# 3      none         none     none     none         pre-calc

# %%
from IPython.display import FileLink, FileLinks

# %%
FileLink('/notebooks/TEST%20Py/mth161.py')
# Out:
# C:\notebooks\TEST%20Py\mth161.py
