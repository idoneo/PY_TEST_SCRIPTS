# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
ff=pd.read_excel('C:/Users/mjc341/desktop/SOURCE RAW DATA files/IPED ACCESS DBS/PIRAFactFinder.xlsx')

# %%
ff
# Out:
#     FALL Cohort  Full-Time-Undergrad_Degree  Part-Time-Undergrad_Degree  \
# 0          2004                        9202                         539
# 1          2005                        9601                         531
# 2          2006                        9674                         516
# 3          2007                        9511                         486
# 4          2008                        9513                         495
# 5          2009                        9268                         587
# 6          2010                        9402                         501
# 7          2011                        9632                         512
# 8          2012                        9759                         478
# 9          2013                       10510                         534
# 10         2014                       10380                         537
# 11         2015                       10291                         477
# ...

# %%
import seaborn as sns
sns.set (color_codes=True)

# %%
ff.plot.scatter(x='New Freshman-Male', y='New Freshman- Female')

# %%
plt.show()

# %%
# Columns is a list
ff.columns
# Out:
# Index(['FALL Cohort', 'Full-Time-Undergrad_Degree',
#        'Part-Time-Undergrad_Degree', 'Total Undergrad Degree',
#        'Full Time Non Degree', 'Part Time Non Degree', 'Total Non Degree',
#        'New Freshman-Male', 'New Freshman- Female', 'Male total Undergrads',
#        'Female total Undergrads', 'Total Freshman_Applied',
#        'Total_freshamn Accepted', 'Total Freshman enrolled', 'yield',
#        'Total transfers applied', 'Total Transfers Accepted',
#        'Total Transfers Enrolled', 'New Freshman_Wht/NonHispn', 'Hispan',
#        'Asian/Pac', 'Black/NonHisp', 'AmerInd', '2ormore', 'UNK',
#        'Total UG_Wht/NonHisp', 'UG-Hispan', 'UG-Asian/Pac', 'UG-Black/NonHisp',
#        'UG-AmerInd', '2ormore.1', 'UG-UNK'],
#       dtype='object')

# %%
ff2 =ff.loc[:,['FALL Cohort','Total Freshman_Applied','Total_freshamn Accepted','Total Freshman enrolled']]

# %%
ff2
# Out:
#     FALL Cohort  Total Freshman_Applied  Total_freshamn Accepted  \
# 0          2004                   18490                     7774
# 1          2005                   18810                     8678
# 2          2006                   19031                     7704
# 3          2007                   19807                     7527
# 4          2008                   21774                     8411
# 5          2009                   21845                     9700
# 6          2010                   25899                    10157
# 7          2011                   27747                    10635
# 8          2012                   27757                    11020
# 9          2013                   28907                    11691
# 10         2014                   31608                    12064
# 11         2015                   33415                    12624
# 12         2016                   32525                    12266
#
#     Total Freshman enrolled
# ...

# %%
ff.values #after seeing the values and  noticing the nan can you replace all nan with 0 or NULL? YES
# Out:
# array([[2004, 9202, 539, 9741, 137, 226, 363, 1161, 875, 4196, 5908, 18490,
#         7774, 2036, 0.26189863648057626, 2670, 1446, 721, 1193, 419, 151,
#         191, 8, nan, 74, 5438, 2673, 655, 1005, 29, nan, 304],
#        [2005, 9601, 531, 10132, 165, 240, 405, 1101, 1175, 4527, 6010,
#         18810, 8678, 2276, 0.2622724129983867, '`', 1324, 651, 1287, 414,
#         138, 178, 6, nan, 253, 5498, 2655, 651, 1009, 27, nan, 697],
#        [2006, 9674, 516, 10190, 144, 175, 319, 1000, 1061, 4689, 5820,
#         19031, 7704, 2061, 0.2675233644859813, 3487, 1355, 656, 1112, 377,
#         125, 170, 4, nan, 273, 5324, 2565, 602, 968, 24, nan, 1026],
#        [2007, 9511, 486, 9997, 166, 216, 382, 934, 1057, 4765, 5614, 19807,
#         7527, 1991, 0.26451441477348214, 3565, 1392, 626, 1000, 407, 129,
#         148, 10, nan, 297, 5050, 2504, 570, 904, 32, nan, 1319],
#        [2008, 9513, 495, 10008, 181, 233, 414, 1006, 1004, 4910, 5512,
# ...

# %%
ff2.plot.hist()

# %%
plt.show()

# %%
sns.set_style("darkgrid")
data = np.random.normal(size=(20,6)) + np.arange (6)/2
sns.boxplot(data=data);

# %%
plt.show()

# %%
sns.set_style ("ticks")

# %%
def sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 7):
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)

# %%
sinplot()

# %%
plt.show()

# %%
sinplot() 
sns.despine()

# %%
plt.show()

# %%
# recall default param
sns.set()

# %%
# there are 4 context sizes the default is notebook otheres are "talk", "poster" and "paper"
sns.set_context("paper")

# %%
FF = ff.loc[:,['FALL Cohort','Total Freshman_Applied']]

# %%
FF
# Out:
#     FALL Cohort  Total Freshman_Applied
# 0          2004                   18490
# 1          2005                   18810
# 2          2006                   19031
# 3          2007                   19807
# 4          2008                   21774
# 5          2009                   21845
# 6          2010                   25899
# 7          2011                   27747
# 8          2012                   27757
# 9          2013                   28907
# 10         2014                   31608
# 11         2015                   33415
# 12         2016                   32525

# %%
sns.set_context("notebook")

# %%
sns.set_style("darkgrid")

# %%
sns.jointplot( x='FALL Cohort',  y ='Total Freshman_Applied', data = FF);

# %%
plt.show()

# %%
sns.jointplot( x='FALL Cohort',  y ='Total_freshamn Accepted', data = ff);

# %%
plt.show()

# %%
sns.jointplot( x='FALL Cohort',  y ='Total Freshman enrolled', data = ff);

# %%
plt.show()

# %%
sns.jointplot( x='FALL Cohort',  y ='Total Freshman enrolled', data = ff, kind="hex", color = "k");

# %%
plt.show()

# %%
sns.regplot(x='Total Freshman_Applied',  y ='Total Freshman enrolled', data = ff);

# %%
plt.show()

# %%
#categorical scatterplot
sns.stripplot(y='Hispan',  x ='Total Freshman enrolled', data = ff);

# %%
plt.show()

# %%
ff=pd.read_excel('C:/Users/mjc341/desktop/IPED ACCESS DBS/PIRAFactFinder.xlsx')

# %%
ff.head()
# Out:
#    FALL Cohort  Full-Time-Undergrad_Degree  Part-Time-Undergrad_Degree  \
# 0         2004                        9202                         539
# 1         2005                        9601                         531
# 2         2006                        9674                         516
# 3         2007                        9511                         486
# 4         2008                        9513                         495
#
#    Total Undergrad Degree  Full Time Non Degree  Part Time Non Degree  \
# 0                    9741                   137                   226
# 1                   10132                   165                   240
# 2                   10190                   144                   175
# 3                    9997                   166                   216
# 4                   10008                   181                   233
#
#    Total Non Degree  New Freshman-Male  New Freshman- Female  \
# ...

# %%
import seaborn as sns
sns.set (color_codes=True)

# %%
sns.stripplot(y='New Freshman-Male',  x ='New Freshman- Female', data = ff);

# %%
plt.show()

# %%
sns.jointplot( x='New Freshman-Male',  y ='New Freshman- Female', data = ff);

# %%
plt.show()

# %%
ff2= ff[['FALL Cohort','New Freshman-Male']]

# %%
ff2.head()
# Out:
#    FALL Cohort  New Freshman-Male
# 0         2004               1161
# 1         2005               1101
# 2         2006               1000
# 3         2007                934
# 4         2008               1006

# %%
ff2.plot.hist()

# %%
plt.show()

# %%
ff2= ff3[['New Freshman-Male','New Freshman- Female']]

# %%
ff2.head(4)
# Out:
#              New Freshman-Male  New Freshman- Female
# FALL Cohort
# 2004                      1161                   875
# 2005                      1101                  1175
# 2006                      1000                  1061
# 2007                       934                  1057

# %%
ff2.plot.hist()

# %%
plt.show()

# %%
ff2.plot.bar()

# %%
plt.show()

# %%
plt.figure();
ff2.iloc[2].plot(kind='bar'); plt.axhline(0,color='k')

# %%
plt.show()

# %%
ff2.plot.barh()

# %%
plt.show()

# %%
ff2.plot.line()

# %%
plt.show()

# %%
ff2.plot(subplots=True, figsize=(6,6));

# %%
plt.show()

# %%
ff4= ff3[['New Freshman_Wht/NonHispn', 'Hispan',
       'Asian/Pac', 'Black/NonHisp', 'AmerInd', '2ormore', 'UNK']]

# %%
ff4.head(4)
# Out:
#              New Freshman_Wht/NonHispn  Hispan  Asian/Pac  Black/NonHisp  \
# FALL Cohort
# 2004                              1193     419        151            191
# 2005                              1287     414        138            178
# 2006                              1112     377        125            170
# 2007                              1000     407        129            148
#
#              AmerInd  2ormore  UNK
# FALL Cohort
# 2004               8      NaN   74
# 2005               6      NaN  253
# 2006               4      NaN  273
# 2007              10      NaN  297

# %%
ff4.plot(subplots=True, figsize=(6,6));

# %%
plt.show()

# %%
ff4.plot(subplots=True, figsize=(10,10));

plt.title ('FACT FINDER ETHNICITY')

# %%
plt.show()

# %%
ff4.plot.line(colormap='gist_rainbow',figsize=(10,10));

# %%
plt.show()

# %%
ff4.plot.barh(colormap='Greens',figsize=(10,10));

# %%
plt.show()

# %%
titanic=sns.load_dataset("titanic")

# %%
titanic.head(4)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
#
#      who adult_male deck  embark_town alive  alone
# 0    man       True  NaN  Southampton    no  False
# 1  woman      False    C    Cherbourg   yes  False
# 2  woman      False  NaN  Southampton   yes   True
# 3  woman      False    C  Southampton   yes  False

# %%
tips=sns.load_dataset("tips")

# %%
tips.head(4)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2

# %%
iris = sns.load_dataset("iris")
sns.pairplot(iris);

# %%
plt.show()

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.stripplot(x="day", y= 'total_bill', data=tips);

# %%
plt.show()

# %%
sns.stripplot(x="day", y= 'total_bill', data=tips,jitter =True);

# %%
plt.show()

# %%
sns.swarmplot(x="day", y= 'total_bill', data=tips);

# %%
plt.show()

# %%
sns.swarmplot(x="day", y= 'total_bill',hue ="sex", data=tips);

# %%
plt.show()

# %%
sns.stripplot( x='FALL Cohort',  y ='Total Freshman_Applied', data = ff);

# %%
plt.show()
