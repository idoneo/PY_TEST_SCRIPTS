# %%
import numpy as np
import pandas as pd

# %%
from scipy import stats, integrate
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set(color_codes = True)

# %%
GPA=pd.read_excel('C:/Users/mjc341/desktop/TESTPY/PY_GPA.xlsx')

# %%
GPA.head(3)
# Out:
#          ID  PersistedFall13  PersistedFall14  PersistedFall15  \
# 0  50100228                1                1                1
# 1  50123504                1                1                1
# 2  50136187                1                1                1
#
#    PersistedFall16  PersistedFall17  YR1 GPA  YR2 GPA  YR3 GPA  YR4 GPA
# 0                1                1    2.389    1.959    1.742    2.041
# 1                1                1    3.744    3.798    3.814    3.743
# 2                1                1    3.438    3.681    3.792    3.798

# %%
sns.set_style ('ticks')
sns.set_style('darkgrid')

# %%
fig, ax = plt.subplots()

# %%
fig.set_size_inches(11.7,8.27)

# %%
YR1= sns.stripplot(x='PersistedFall13', y= 'YR1 GPA', data= GPA, jitter=True,linewidth = 1,size = 7);

# %%
sns.despine()
plt.title('2012 YR1 GPA and Persistence')

# %%
plt.show()

# %%
fig.savefig('example3jitter.png')

# %%
sns.set_style ('ticks')
sns.set_style('darkgrid')
fig, ax = plt.subplots()
fig.set_size_inches(11.7,8.27)

# %%
YR2= sns.stripplot(x='PersistedFall14', y= 'YR2 GPA', data= GPA, jitter=True,linewidth = 1,size = 7);
sns.despine()
plt.title('2012 YR2 GPA and Persistence')

# %%
plt.show()

# %%
fig.savefig('example4jitter.png')

# %%
sns.set_style ('ticks')
sns.set_style('darkgrid')
fig, ax = plt.subplots()
fig.set_size_inches(11.7,8.27)

# %%
YR3= sns.stripplot(x='PersistedFall15', y= 'YR3 GPA', data= GPA, jitter=True,linewidth = 1,size = 7);
sns.despine()
plt.title('2012 YR3 GPA and Persistence')

# %%
plt.show()

# %%
fig.savefig('example5jitter.png')

# %%
sns.set_style ('ticks')
sns.set_style('darkgrid')
fig, ax = plt.subplots()
fig.set_size_inches(11.7,8.27)
YR4= sns.stripplot(x='PersistedFall16', y= 'YR4 GPA', data= GPA, jitter=True,linewidth = 1,size = 7);
sns.despine()
plt.title('2012 YR4 GPA and Persistence')

# %%
plt.show()

# %%
fig.savefig('example6jitter.png')

# %%
sns.boxplot(x='PersistedFall14', y= 'YR2 GPA', data= GPA,);

# %%
plt.show()

# %%
GPA2=pd.read_excel('C:/Users/mjc341/desktop/TESTPY/PY_GPA2.xlsx')

# %%
GPA2.head()
# Out:
#          ID  YR 1  YR 2  YR 3  YR 4  YR1 GPA  YR2 GPA  YR3 GPA  YR4 GPA
# 0  50100228     1     1     1     1    2.389    1.959    1.742    2.041
# 1  50123504     1     1     1     1    3.744    3.798    3.814    3.743
# 2  50136187     1     1     1     1    3.438    3.681    3.792    3.798
# 3  50158224     1     1     1     1    4.000    4.000    3.886    3.902
# 4  50167947     1     1     1     1    3.078    3.169    3.111    3.159

# %%
YR1GPA=sns.stripplot(x='YR 1', y= 'YR1 GPA', data= GPA2, jitter=True);

# %%
plt.show()

# %%
YR2GPA=sns.stripplot(x='YR 2', y= 'YR2 GPA', data= GPA2, jitter=True);

# %%
plt.show()

# %%
YR3GPA=sns.stripplot(x='YR 3', y= 'YR3 GPA', data= GPA2, jitter=True);

# %%
plt.show()

# %%
YR4GPA=sns.stripplot(x='YR 4', y= 'YR4 GPA', data= GPA2, jitter=True);

# %%
plt.show()

# %%
GPA3=pd.read_excel('C:/Users/mjc341/desktop/TESTPY/GPA3.xlsx')

# %%
GPA3.head()
# Out:
#          ID  GRAD-NOGRAD  GPA YR 4
# 0  50361632            0     1.216
# 1  50371117            0     1.293
# 2  50301424            0     1.373
# 3  50368402            0     1.410
# 4  50364481            0     1.483

# %%
GPA3=sns.stripplot(x='GRAD-NOGRAD', y= 'GPA YR 4', data= GPA3, jitter=True);

# %%
plt.show()
