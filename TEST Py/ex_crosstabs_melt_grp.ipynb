# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
#FIND DUPLICATES
if dfx['APPLICANT_ID'].size == dfx['APPLICANT_ID'].unique().size:
    print("Unique")
else:
    print("Not unique")
# Out:
# Unique

# %%
#delete a col
del dfx['STUDENT_CAMPUS_ID']

# %%
dfx['COUNTRY_OF_RESIDENCE'].unique()
# Out:
# array(['-', 'FRA', 'USA', 'ECU', 'BGD', 'TWN', 'CHN', 'CHE', 'TUR'], dtype=object)

# %%
dfx['STATE_OF_RESIDENCE'].unique()
# Out:
# array(['-', 'FL', 'NY', 'CA', 'ZH', 'NJ', 'IL', 'TN', 'VA', 'MA'], dtype=object)

# %%
mask = dfx['ADMITTED'] == 1
dfx2 =dfx[mask]

# %%
dfx2.head(4)
# Out:
#     APPLICANT_ID                   APPLICANT_NAME GENDER  \
# 6       50376133                    Masroor,Faraz   Male
# 7       50379757  Winegardner,Alexander Schilling   Male
# 9       50417893                       Yeo,Wonjun   Male
# 10      50426545                    Marine,Matias   Male
#
#    APPLICANT_ETHNIC_GROUP NOTIFICATION_PLAN FINAL_NOTIFICATION_PLAN  \
# 6           Not Specified               REG                     REG
# 7           Not Specified               ED2                     ED2
# 9                   Asian                EA                      EA
# 10        Hispanic/Latino                EA                      EA
#
#    ACADEMIC_CAREER_CODE ACADEMIC_CAREER ACADEMIC_PROGRAM_CODE  \
# 6                  UGRD   Undergraduate                  UGAS
# 7                  UGRD   Undergraduate                  UGAS
# 9                  UGRD   Undergraduate                  UGBU
# 10                 UGRD   Undergraduate                  UGAS
#
# ...

# %%
dfx2['APPLICANT_ID'].count()
# Out:
# 57

# %%
dfx['APPLICANT_ID'].count()
# Out:
# 99

# %%
x= dfx2['APPLICANT_ID'].count()

# %%
y=dfx['APPLICANT_ID'].count()

# %%
x/y*100
# Out:
# 57.575757575757578

# %%
pd.melt(dfx, id_vars=['APPLICANT_ID'], value_vars=['APPLICANT_ETHNIC_GROUP']).head(5)
# Out:
#    APPLICANT_ID                variable            value
# 0      50050387  APPLICANT_ETHNIC_GROUP  Hispanic/Latino
# 1      50178914  APPLICANT_ETHNIC_GROUP    Not Specified
# 2      50238897  APPLICANT_ETHNIC_GROUP    Not Specified
# 3      50266806  APPLICANT_ETHNIC_GROUP    Not Specified
# 4      50297494  APPLICANT_ETHNIC_GROUP            White

# %%
pd.crosstab(dfx['APPLICANT_ID'],dfx['APPLICANT_ETHNIC_GROUP']).head(10)
# Out:
# APPLICANT_ETHNIC_GROUP  Asian  Black/African American  Hispanic/Latino  \
# APPLICANT_ID
# 50050387                    0                       0                1
# 50178914                    0                       0                0
# 50238897                    0                       0                0
# 50266806                    0                       0                0
# 50297494                    0                       0                0
# 50300554                    0                       0                0
# 50376133                    0                       0                0
# 50379757                    0                       0                0
# 50417521                    0                       0                1
# 50417893                    1                       0                0
#
# APPLICANT_ETHNIC_GROUP  Not Available  Not Specified  Two or More Races  White
# APPLICANT_ID
# 50050387                            0              0                  0      0
# ...

# %%
dfxsubset = dfx[(dfx['NET_DEPOSITS']== 1)]

# %%
dfxsubset.head(10)
# Out:
#     APPLICANT_ID                   APPLICANT_NAME  GENDER  \
# 7       50379757  Winegardner,Alexander Schilling    Male
# 9       50417893                       Yeo,Wonjun    Male
# 16      51793645                    Nash,Bryson W    Male
# 25      54042947                    Chen,Jingdong    Male
# 26      54047458               Elsas,Robert Lucas    Male
# 31      54076026           Bachmann,Calder Vikram    Male
# 35      54088931          Braddock,Sarah Victoria  Female
# 39      54095793                      Doyle,Laura  Female
# 40      54109522                    Vignau,Alexia  Female
# 44      54121947           Schneider,Samantha Sue  Female
#
#    APPLICANT_ETHNIC_GROUP NOTIFICATION_PLAN FINAL_NOTIFICATION_PLAN  \
# 7           Not Specified               ED2                     ED2
# 9                   Asian                EA                      EA
# 16          Not Available                EA                      EA
# ...

# %%
dfxsubset.shape
# Out:
# (29, 49)

# %%
#29 rows 49 cols
#group data
#group = dfx.groupby(['APPLICANT_ETHNIC_GROUP','COUNTRY_OF_RESIDENCE']) DID not group

# %%
#qry= dfx.query((['col_name'] == value))

# %%
#Get descriptive statistics for a specified column
#dfx.col_name.describe()  for integers values gives mean std min max quartiles
#Group data and obtain the mean values   grpagg = ver.groupby('purchaser_type_name').aggregate(np.mean)
#grpagg
#Group data and get the sums
#grpsum = ver.groupby('purchaser_type_name').aggregate(np.sum)
#grpsum

# %%
criterion = dfx['APPLICANT_ETHNIC_GROUP'].map(lambda x: x.startswith('B'))
criterion.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: APPLICANT_ETHNIC_GROUP, dtype: bool

# %%
MTH = pd.read_excel('C:/Users/mjc341/desktop/TESTPY/PY_MTH_CRSES.xlsx')

# %%
MTH.head(2)
# Out:
#          ID Career  Admit Term Admit Type Acad Prog  Course ID EarnCredit  \
# 0  50025963   UGRD        2158        XFR      UGBU     101267          Y
# 1  50025963   UGRD        2158        XFR      UGBU     108140          Y
#
#    Artic Term   Eff Date  Appl Nbr       ...        Descr Grading Transfer  \
# 0        2168 2014-08-22    133455       ...          NaN     TRN      3.0
# 1        2168 2014-08-22    133455       ...          NaN     TRN      3.0
#
#   Subject  Catalog       COURSE Sequence Grd Scheme Grade  Grade Category
# 0     MTH      O99  MTH     O99        1        UGD     B            TRAN
# 1     MTH      101     MTH  101        1        UGD     B            TRAN
#
# [2 rows x 23 columns]

# %%
pd.crosstab(MTH.COURSE, MTH.ID, margins=True)
# Out:
# ID         50025963  50034173  50035159  50035785  50038222  50040434  \
# COURSE
# ARH  107          0         0         0         0         0         0
# ART  105          0         0         0         0         0         0
# ART  107          0         0         0         0         0         0
# ART  108          0         0         0         0         0         0
# BIL  105          0         0         0         0         0         0
# BIL  107          0         0         0         0         0         0
# BIL  108          0         0         0         0         0         0
# BIL  113          0         0         0         0         0         0
# CHM  105          0         2         0         1         0         0
# CHM  113          0         0         0         0         0         0
# COM  105          0         0         0         0         0         0
# DAN  130          0         0         0         0         0         0
# ...

# %%
CRS = pd.crosstab(MTH.ID, MTH.COURSE,  margins=True)

# %%
CRS.head(2)
# Out:
# COURSE    ARH  107  ART  105  ART  107  ART  108  BIL  105  BIL  107  \
# ID
# 50025963         0         0         0         0         0         0
# 50034173         0         0         0         0         0         0
#
# COURSE    BIL  108  BIL  113  CHM  105  CHM  113 ...   PHY  107  PHY  108  \
# ID                                               ...
# 50025963         0         0         0         0 ...          0         0
# 50034173         0         0         2         0 ...          0         0
#
# COURSE    POR  105  SPA  105  SPA  107  TAL  107  THA  105  THA  113  \
# ID
# 50025963         0         0         0         0         0         0
# 50034173         0         0         0         0         0         0
#
# COURSE    THA  140  All
# ID
# 50025963         0    4
# 50034173         0    3
#
# [2 rows x 83 columns]

# %%
CRS.columns
# Out:
# Index(['ARH  107', 'ART  105', 'ART  107', 'ART  108', 'BIL  105', 'BIL  107',
#        'BIL  108', 'BIL  113', 'CHM  105', 'CHM  113', 'COM  105', 'DAN  130',
#        'ECS  113', 'ENG  105', 'ENG  107', 'ENG  108', 'FRE  105', 'GEG  105',
#        'GEG  107', 'GSC  105', 'GSC  107', 'HIS  105', 'JMM  108', 'MCY  140',
#        'MKP  140', 'MMI  107', 'MMI  108', 'MMI  140', 'MSC  107', 'MSC  108',
#        'MSJ  107', 'MSJ  108', 'MSJ  113', 'MTC  107', 'MTC  108', 'MTC  140',
#        'MTH     O99', 'MTH  100T', 'MTH  101', 'MTH  103', 'MTH  104',
#        'MTH  105', 'MTH  106', 'MTH  107', 'MTH  108', 'MTH  109', 'MTH  111',
#        'MTH  112', 'MTH  113', 'MTH  114', 'MTH  11T', 'MTH  130', 'MTH  131',
#        'MTH  140', 'MTH  141', 'MTH  151', 'MTH  161', 'MTH  162', 'MTH  171',
#        'MTH  172', 'MTH  199', 'MTH  200T', 'MTH  210', 'MTH  211', 'MTH  224',
#        'MTH  300T', 'MTH  301', 'MTH  309', 'MTH  310', 'MTH  311',
# ...

# %%
value_list = ['MTH']

# %%
MTHb = [MTH.Subject.isin(value_list)]

# %%
MTHb[MTH.Subject.isin(value_list)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-ba1333eee117> in <module>()
# ----> 1 MTHb[MTH.Subject.isin(value_list)]
#
# TypeError: list indices must be integers or slices, not Series

# %%
MTH.head(2)
# Out:
#          ID Career  Admit Term Admit Type Acad Prog  Course ID EarnCredit  \
# 0  50025963   UGRD        2158        XFR      UGBU     101267          Y
# 1  50025963   UGRD        2158        XFR      UGBU     108140          Y
#
#    Artic Term   Eff Date  Appl Nbr       ...        Descr Grading Transfer  \
# 0        2168 2014-08-22    133455       ...          NaN     TRN      3.0
# 1        2168 2014-08-22    133455       ...          NaN     TRN      3.0
#
#   Subject  Catalog       COURSE Sequence Grd Scheme Grade  Grade Category
# 0     MTH      O99  MTH     O99        1        UGD     B            TRAN
# 1     MTH      101     MTH  101        1        UGD     B            TRAN
#
# [2 rows x 23 columns]

# %%
MTH.columns
# Out:
# Index(['ID', 'Career', 'Admit Term', 'Admit Type', 'Acad Prog', 'Course ID',
#        'EarnCredit', 'Artic Term', 'Eff Date', 'Appl Nbr', 'Year', 'Sch Subj',
#        'Course Nbr', 'Descr', 'Grading', 'Transfer', 'Subject', 'Catalog',
#        'COURSE', 'Sequence', 'Grd Scheme', 'Grade', 'Grade Category'],
#       dtype='object')

# %%
value_list = ['MTH']

# %%
MTH1= MTH[MTH.Subject.isin(value_list)]

# %%
CRS2 = pd.crosstab(MTH1.ID, MTH.COURSE,  margins=True)

# %%
CRS2.head(2)
# Out:
# COURSE      MTH     O99  MTH  100T  MTH  101  MTH  103  MTH  104  MTH  105  \
# ID
# 50025963.0            1          0         1         0         0         0
# 50035159.0            0          1         1         0         0         0
#
# COURSE      MTH  106  MTH  107  MTH  108  MTH  109 ...   MTH  210  MTH  211  \
# ID                                                 ...
# 50025963.0         0         0         0         0 ...          0         0
# 50035159.0         0         0         0         0 ...          0         0
#
# COURSE      MTH  224  MTH  300T  MTH  301  MTH  309  MTH  310  MTH  311  \
# ID
# 50025963.0         0          0         0         0         0         0
# 50035159.0         0          0         0         0         0         0
#
# COURSE      MTH  400T  All
# ID
# 50025963.0          0    3
# 50035159.0          0    3
#
# [2 rows x 36 columns]

# %%
MTH1.head(2)
# Out:
#          ID Career  Admit Term Admit Type Acad Prog  Course ID EarnCredit  \
# 0  50025963   UGRD        2158        XFR      UGBU     101267          Y
# 1  50025963   UGRD        2158        XFR      UGBU     108140          Y
#
#    Artic Term   Eff Date  Appl Nbr       ...        Descr Grading Transfer  \
# 0        2168 2014-08-22    133455       ...          NaN     TRN      3.0
# 1        2168 2014-08-22    133455       ...          NaN     TRN      3.0
#
#   Subject  Catalog       COURSE Sequence Grd Scheme Grade  Grade Category
# 0     MTH      O99  MTH     O99        1        UGD     B            TRAN
# 1     MTH      101     MTH  101        1        UGD     B            TRAN
#
# [2 rows x 23 columns]

# %%
value_list2 = ['MTH 140','MTH 141','MTH 151','MTH 161','MTH 162','MTH 171','MTH 172']

# %%
MTH3= MTH[MTH.COURSE.isin(value_list)]

# %%
MTH3.head(3)
# Out:
# Empty DataFrame
# Columns: [ID, Career, Admit Term, Admit Type, Acad Prog, Course ID, EarnCredit, Artic Term, Eff Date, Appl Nbr, Year, Sch Subj, Course Nbr, Descr, Grading, Transfer, Subject, Catalog, COURSE, Sequence, Grd Scheme, Grade, Grade Category]
# Index: []
#
# [0 rows x 23 columns]

# %%
MTH.info
# Out:
# <bound method DataFrame.info of              ID Career  Admit Term Admit Type Acad Prog  Course ID EarnCredit  \
# 0      50025963   UGRD        2158        XFR      UGBU     101267          Y
# 1      50025963   UGRD        2158        XFR      UGBU     108140          Y
# 2      50025963   UGRD        2158        XFR      UGBU     111200          Y
# 3      50025963   UGRD        2158        XFR      UGBU     116153          Y
# 4      50034173   UGRD        2148        XFR      UGNU     110064          N
# 5      50034173   UGRD        2148        XFR      UGNU     110064          Y
# 6      50034173   UGRD        2148        XFR      UGNU     111200          Y
# 7      50035159   UGRD        2138        XFR      UGAS     108140          Y
# 8      50035159   UGRD        2138        XFR      UGAS     111200          N
# 9      50035159   UGRD        2138        XFR      UGAS     111200          Y
# 10     50035159   UGRD        2138        XFR      UGAS     116155          Y
# ...

# %%
MTH.columns
# Out:
# Index(['ID', 'Career', 'Admit Term', 'Admit Type', 'Acad Prog', 'Course ID',
#        'EarnCredit', 'Artic Term', 'Eff Date', 'Appl Nbr', 'Year', 'Sch Subj',
#        'Course Nbr', 'Descr', 'Grading', 'Transfer', 'Subject', 'Catalog',
#        'COURSE', 'Sequence', 'Grd Scheme', 'Grade', 'Grade Category'],
#       dtype='object')

# %%
MTH['COURSE'].describe
# Out:
# <bound method NDFrame.describe of 0        MTH     O99
# 1           MTH  101
# 2           ENG  105
# 3           MTH  113
# 4           CHM  105
# 5           CHM  105
# 6           ENG  105
# 7           MTH  101
# 8           ENG  105
# 9           ENG  105
# 10          MTH  130
# 11         MTH  100T
# 12       MTH     O99
# 13          MTH  101
# 14          CHM  105
# 15          ENG  105
# 16          MTH  101
# 17          MTH  101
# 18          ENG  105
# 19          MTH  107
# 20          MTH  107
# 21          MTH  11T
# 22          MTH  101
# 23          MTH  109
# 24          ENG  105
# 25         MTH  100T
# 26       MTH     O99
# 27          MTH  101
# 28          CHM  105
# 29          ENG  105
#             ...
# 38460       ENG  105
# 38461       MTH  130
# 38462    MTH     O99
# 38463       MTH  107
# 38464       MTH  101
# 38465       ENG  105
# 38466      MTH  100T
# 38467      MTH  100T
# 38468      MTH  100T
# 38469       ENG  105
# 38470       ENG  105
# ...

# %%
MTH[['COURSE']]=MTH[['COURSE']].astype(str)

# %%
MTH3= MTH[MTH.COURSE.isin(value_list2)]

# %%
MTH3.head()
# Out:
# Empty DataFrame
# Columns: [ID, Career, Admit Term, Admit Type, Acad Prog, Course ID, EarnCredit, Artic Term, Eff Date, Appl Nbr, Year, Sch Subj, Course Nbr, Descr, Grading, Transfer, Subject, Catalog, COURSE, Sequence, Grd Scheme, Grade, Grade Category]
# Index: []
#
# [0 rows x 23 columns]
