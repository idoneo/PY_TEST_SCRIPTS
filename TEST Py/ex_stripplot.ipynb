# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
from scipy import stats,integrate
import matplotlib.pyplot as plt
import seaborn as sns
sns.set (color_codes=True)

# %%
GR=pd.read_excel('C:/Users/mjc341/desktop/TESTPY/2158GR.xlsx')

# %%
GR.head()
# Out:
#    APPLICANT_ID        ADMIT_TYPE  APPLICANT_ETHNIC_GROUP UGAS/UGBU(econ)  \
# 0      50432885       New Student                   White            UGBU
# 1      50457667       New Student                   White            UGBU
# 2      50475188  Transfer Student                   White            UGBU
# 3      50480064       New Student  Black/African American            UGBU
# 4      50480105       New Student         Hispanic/Latino            UGBU
#
#    MTH161-TEST/COURSE CREDIT  MAS201CourseCredit  MTH 161 TERM  MAS 201 Term  \
# 0                          0                   0             0          2161
# 1                          0                   0             0          2161
# 2                          1                   0             0          2161
# 3                          0                   0             0             0
# 4                          0                   0             0          2168
#
# ...

# %%
sns.stripplot(x='ADMIT_TYPE', y= 'Most.Recent.Cumulative.GPA', data=GR,jitter =True,);

# %%
plt.show()

# %%
sns.stripplot(x='EXT Degree', y= 'Most.Recent.Cumulative.GPA', data=GR,jitter =True,);

# %%
plt.show()

# %%
sns.stripplot(x='MAS 201 Term', y= 'Most.Recent.Cumulative.GPA', data=GR,jitter =True,);

# %%
plt.show()

# %%
sns.stripplot(x='MAS 201 Grade', y= 'Most.Recent.Cumulative.GPA', data=GR,jitter =True,);

# %%
plt.show()
