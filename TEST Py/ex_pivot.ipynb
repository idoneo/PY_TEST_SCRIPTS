# %%
import numpy as NP
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
GPA=pd.read_excel('C:/Users/mjc341/Desktop/TESTPY/GPA_TEST_PIVOT_2138-88.xlsx')

# %%
GPA.head(3)
# Out:
#          ID  Group Name Career  S-TERM    GPA
# 0  50412946        2168   UGRD    2168  2.744
# 1  50412946        2168   UGRD    2165  2.696
# 2  50412946        2168   UGRD    2161  2.648

# %%
GPA2= GPA.pivot(index='ID',columns='S-TERM',values='GPA')

# %%
GPA2.head(3)
# Out:
# S-TERM    2138   2141   2145   2148   2151   2155   2158   2161   2165   2168  \
# ID
# 50016060  3.95  3.950  3.957  3.967  3.970  3.973  3.973  3.973  3.975  3.977
# 50017756  3.57  3.582  3.623  3.579  3.607    NaN    NaN  3.476  3.476  3.450
# 50017823   NaN  4.000    NaN  3.350    NaN    NaN    NaN    NaN    NaN    NaN
#
# S-TERM     2171  2175  2178   2181   2185   2188
# ID
# 50016060  3.977   NaN   NaN  3.977  3.977  3.977
# 50017756  3.450  3.45  3.45    NaN    NaN    NaN
# 50017823    NaN   NaN   NaN    NaN    NaN    NaN

# %%
GPA2.info
# Out:
# <bound method DataFrame.info of S-TERM    1651  1658  1661  1665  1678  1681  1688  1691  1695  1698  ...    \
# ID                                                                    ...
# 50015400   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 50015452   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 50015463   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 50015731   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 50015778   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 50015968   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 50016060   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 50017295   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 50017483   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 50017756   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ...

# %%
GPA2.to_excel("pivotedGPAs.xlsx")
