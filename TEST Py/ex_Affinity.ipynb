# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
AF1 = pd.read_excel('C:/Users/mjc341/Desktop/UMAN 1502 Affinity/Affinity_pop_1.xlsx')

# %%
AF2 = pd.read_excel('C:/Users/mjc341/Desktop/UMAN 1502 Affinity/Afffinity_pop_2.xlsx')

# %%
AF2.head(2)
# Out:
#   Contact ID (18-digit)  Common App ID  Application Number     Empl ID  \
# 0    0031500001eJmOrAAK     19092179.0            350719.0  54311370.0
# 1    0031500001pqNJCAA2     15769046.0            279998.0  54238140.0
#
#                      Email Notification Plan Opportunity Record Type  \
# 0  williamsa4321@gmail.com               REG         UGrad Applicant
# 1    ebraun12321@gmail.com               REG         UGrad Applicant
#
#                School / College            Recruitment Program  \
# 0       School of Communication  Communication - Undergraduate
# 1  College of Arts and Sciences   Theatre Arts - Undergraduate
#
#                    Initial Recruitment Plan  \
# 0  Bachelor - Undecided (Arts and Sciences)
# 1                Bachelor - Musical Theatre
#
#                    ...                     Admit Type Inquiry First Name  \
# 0                  ...                    New Student     1.0       Alea
# ...

# %%
AF1.head(2)
# Out:
#   Contact ID (18-digit)  Common App ID  Application Number  Empl ID  \
# 0    0031500001kQZbBAAW            NaN                 NaN      NaN
# 1    0031500001eLC9iAAG            NaN                 NaN      NaN
#
#                           Email Notification Plan Opportunity Record Type  \
# 0                 cmqr07@me.com               NaN           UGrad Inquiry
# 1  3240en@student.montverde.org               NaN           UGrad Inquiry
#
#                     School / College        Recruitment Program  \
# 0  School of Business Administration   Business - Undergraduate
# 1       College of Arts and Sciences  Undecided - Undergraduate
#
#            Initial Recruitment Plan  \
# 0  Bachelor - Undecided (Education)
# 1            Bachelor - Criminology
#
#                          ...                           Admit Type Inquiry  \
# 0                        ...                          New Student     1.0
# ...

# %%
AF1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 345375 entries, 0 to 345374
# Data columns (total 22 columns):
# Contact ID (18-digit)                     345373 non-null object
# Common App ID                             67000 non-null float64
# Application Number                        67098 non-null float64
# Empl ID                                   70600 non-null float64
# Email                                     342283 non-null object
# Notification Plan                         66967 non-null object
# Opportunity Record Type                   345368 non-null object
# School / College                          345271 non-null object
# Recruitment Program                       345271 non-null object
# Initial Recruitment Plan                  345281 non-null object
# Academic Plan: Plan Type                  67103 non-null object
# Term: Term Name                           345368 non-null object
# Admit Type                                345368 non-null object
# ...

# %%
AF2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97683 entries, 0 to 97682
# Data columns (total 22 columns):
# Contact ID (18-digit)                     97681 non-null object
# Common App ID                             97177 non-null float64
# Application Number                        97676 non-null float64
# Empl ID                                   97676 non-null float64
# Email                                     97663 non-null object
# Notification Plan                         97539 non-null object
# Opportunity Record Type                   97676 non-null object
# School / College                          97397 non-null object
# Recruitment Program                       97397 non-null object
# Initial Recruitment Plan                  97456 non-null object
# Academic Plan: Plan Type                  97676 non-null object
# Term: Term Name                           97676 non-null object
# Admit Type                                97676 non-null object
# ...

# %%
AF3 = AF2.append(AF1)

# %%
AF3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 443058 entries, 0 to 345374
# Data columns (total 22 columns):
# Contact ID (18-digit)                     443054 non-null object
# Common App ID                             164177 non-null float64
# Application Number                        164774 non-null float64
# Empl ID                                   168276 non-null float64
# Email                                     439946 non-null object
# Notification Plan                         164506 non-null object
# Opportunity Record Type                   443044 non-null object
# School / College                          442668 non-null object
# Recruitment Program                       442668 non-null object
# Initial Recruitment Plan                  442737 non-null object
# Academic Plan: Plan Type                  164779 non-null object
# Term: Term Name                           443044 non-null object
# Admit Type                                443044 non-null object
# ...

# %%
345375 + 97683
# Out:
# 443058

# %%
AF3.columns
# Out:
# Index(['Contact ID (18-digit)', 'Common App ID', 'Application Number',
#        'Empl ID', 'Email', 'Notification Plan', 'Opportunity Record Type',
#        'School / College', 'Recruitment Program', 'Initial Recruitment Plan',
#        'Academic Plan: Plan Type', 'Term: Term Name', 'Admit Type', 'Inquiry',
#        'First Name', 'Last Name', 'Mailing City', 'Mailing State/Province',
#        'Mailing Zip/Postal Code', 'Inquiry Date', 'First Inquiry Source',
#        'Primary Campaign Source: Campaign Name'],
#       dtype='object')

# %%
AF4 = AF3.rename(columns ={'Contact ID (18-digit)': 'ID_CONTACT', 'Common App ID': 'ID_COMN_APP', 'Application Number': 'ID_APPL',
       'Empl ID': 'EMPLID', 'Email': 'EMAIL', 'Notification Plan': 'NOTIF_PLN', 'Opportunity Record Type': 'OPP_RECORD',
       'School / College':'SCHOOL', 'Recruitment Program': 'RECRUIT', 'Initial Recruitment Plan':'INIT_RECRUIT_PLN',
       'Academic Plan: Plan Type':'ACAD_PLN', 'Term: Term Name':'TERM', 'Admit Type':"ADMT_TYPE", 'Inquiry':'INQ',
       'First Name':'FNAME', 'Last Name':'LNAME', 'Mailing City':'CITY', 'Mailing State/Province':'STATE',
       'Mailing Zip/Postal Code':'ZIP', 'Inquiry Date':'INQ_DATE', 'First Inquiry Source':'FIRST_INQ_SRCE',
       'Primary Campaign Source: Campaign Name':'CAMPAIGN'})

# %%
AF4.columns
# Out:
# Index(['ID_CONTACT', 'ID_COMN_APP', 'ID_APPL', 'EMPLID', 'EMAIL', 'NOTIF_PLN',
#        'OPP_RECORD', 'SCHOOL', 'RECRUIT', 'INIT_RECRUIT_PLN', 'ACAD_PLN',
#        'TERM', 'ADMT_TYPE', 'INQ', 'FNAME', 'LNAME', 'CITY', 'STATE', 'ZIP',
#        'INQ_DATE', 'FIRST_INQ_SRCE', 'CAMPAIGN'],
#       dtype='object')

# %%
AF4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 443058 entries, 0 to 345374
# Data columns (total 22 columns):
# ID_CONTACT          443054 non-null object
# ID_COMN_APP         164177 non-null float64
# ID_APPL             164774 non-null float64
# EMPLID              168276 non-null float64
# EMAIL               439946 non-null object
# NOTIF_PLN           164506 non-null object
# OPP_RECORD          443044 non-null object
# SCHOOL              442668 non-null object
# RECRUIT             442668 non-null object
# INIT_RECRUIT_PLN    442737 non-null object
# ACAD_PLN            164779 non-null object
# TERM                443044 non-null object
# ADMT_TYPE           443044 non-null object
# INQ                 443044 non-null float64
# FNAME               443042 non-null object
# LNAME               443044 non-null object
# CITY                435064 non-null object
# STATE               409457 non-null object
# ZIP                 426683 non-null object
# ...

# %%
AF4.count()
# Out:
# ID_CONTACT          443054
# ID_COMN_APP         164177
# ID_APPL             164774
# EMPLID              168276
# EMAIL               439946
# NOTIF_PLN           164506
# OPP_RECORD          443044
# SCHOOL              442668
# RECRUIT             442668
# INIT_RECRUIT_PLN    442737
# ACAD_PLN            164779
# TERM                443044
# ADMT_TYPE           443044
# INQ                 443044
# FNAME               443042
# LNAME               443044
# CITY                435064
# STATE               409457
# ZIP                 426683
# INQ_DATE            412386
# FIRST_INQ_SRCE      443024
# CAMPAIGN            276700
# dtype: int64

# %%
AF5 = AF4.dropna()

# %%
#AF5 is the df that has values for every column
AF5.count()
# Out:
# ID_CONTACT          125840
# ID_COMN_APP         125840
# ID_APPL             125840
# EMPLID              125840
# EMAIL               125840
# NOTIF_PLN           125840
# OPP_RECORD          125840
# SCHOOL              125840
# RECRUIT             125840
# INIT_RECRUIT_PLN    125840
# ACAD_PLN            125840
# TERM                125840
# ADMT_TYPE           125840
# INQ                 125840
# FNAME               125840
# LNAME               125840
# CITY                125840
# STATE               125840
# ZIP                 125840
# INQ_DATE            125840
# FIRST_INQ_SRCE      125840
# CAMPAIGN            125840
# dtype: int64

# %%
AF6 = AF4.dropna([0])

# %%
AF6.count()
# Out:
# ID_CONTACT          125840
# ID_COMN_APP         125840
# ID_APPL             125840
# EMPLID              125840
# EMAIL               125840
# NOTIF_PLN           125840
# OPP_RECORD          125840
# SCHOOL              125840
# RECRUIT             125840
# INIT_RECRUIT_PLN    125840
# ACAD_PLN            125840
# TERM                125840
# ADMT_TYPE           125840
# INQ                 125840
# FNAME               125840
# LNAME               125840
# CITY                125840
# STATE               125840
# ZIP                 125840
# INQ_DATE            125840
# FIRST_INQ_SRCE      125840
# CAMPAIGN            125840
# dtype: int64

# %%
AF7 = AF4.dropna(how= 'all')

# %%
AF7.count()
# Out:
# ID_CONTACT          443054
# ID_COMN_APP         164177
# ID_APPL             164774
# EMPLID              168276
# EMAIL               439946
# NOTIF_PLN           164506
# OPP_RECORD          443044
# SCHOOL              442668
# RECRUIT             442668
# INIT_RECRUIT_PLN    442737
# ACAD_PLN            164779
# TERM                443044
# ADMT_TYPE           443044
# INQ                 443044
# FNAME               443042
# LNAME               443044
# CITY                435064
# STATE               409457
# ZIP                 426683
# INQ_DATE            412386
# FIRST_INQ_SRCE      443024
# CAMPAIGN            276700
# dtype: int64

# %%
AF8 = AF4.dropna(subset =['EMPLID'])

# %%
#AF8 is subset where there is an emplid
AF8.count()
# Out:
# ID_CONTACT          168276
# ID_COMN_APP         164177
# ID_APPL             164774
# EMPLID              168276
# EMAIL               168261
# NOTIF_PLN           164506
# OPP_RECORD          168276
# SCHOOL              167961
# RECRUIT             167961
# INIT_RECRUIT_PLN    168030
# ACAD_PLN            164774
# TERM                168276
# ADMT_TYPE           168276
# INQ                 168276
# FNAME               168276
# LNAME               168276
# CITY                168126
# STATE               153102
# ZIP                 166133
# INQ_DATE            137676
# FIRST_INQ_SRCE      168272
# CAMPAIGN            148104
# dtype: int64

# %%
AF4.head(5)
# Out:
#            ID_CONTACT  ID_COMN_APP   ID_APPL      EMPLID  \
# 0  0031500001eJmOrAAK   19092179.0  350719.0  54311370.0
# 1  0031500001pqNJCAA2   15769046.0  279998.0  54238140.0
# 2  0031500001rQaOMAA0   16921934.0  292329.0  54251168.0
# 3  0031500001rSD9AAAW   17405031.0  293286.0  54249230.0
# 4  0031500001dQ5xrAAC   15950268.0  284830.0  54242433.0
#
#                                 EMAIL NOTIF_PLN       OPP_RECORD  \
# 0             williamsa4321@gmail.com       REG  UGrad Applicant
# 1               ebraun12321@gmail.com       REG  UGrad Applicant
# 2       ambiance.alirezai99@gmail.com       REG  UGrad Applicant
# 3           edward.ke.lin@foxmail.com       REG  UGrad Applicant
# 4  pierre.jones.17@wheels-student.org       REG  UGrad Applicant
#
#                          SCHOOL                        RECRUIT  \
# 0       School of Communication  Communication - Undergraduate
# 1  College of Arts and Sciences   Theatre Arts - Undergraduate
# ...

# %%
AF4.isnull().any()
# Out:
# ID_CONTACT          True
# ID_COMN_APP         True
# ID_APPL             True
# EMPLID              True
# EMAIL               True
# NOTIF_PLN           True
# OPP_RECORD          True
# SCHOOL              True
# RECRUIT             True
# INIT_RECRUIT_PLN    True
# ACAD_PLN            True
# TERM                True
# ADMT_TYPE           True
# INQ                 True
# FNAME               True
# LNAME               True
# CITY                True
# STATE               True
# ZIP                 True
# INQ_DATE            True
# FIRST_INQ_SRCE      True
# CAMPAIGN            True
# dtype: bool

# %%
AF4.isnull().sum()
# Out:
# ID_CONTACT               4
# ID_COMN_APP         278881
# ID_APPL             278284
# EMPLID              274782
# EMAIL                 3112
# NOTIF_PLN           278552
# OPP_RECORD              14
# SCHOOL                 390
# RECRUIT                390
# INIT_RECRUIT_PLN       321
# ACAD_PLN            278279
# TERM                    14
# ADMT_TYPE               14
# INQ                     14
# FNAME                   16
# LNAME                   14
# CITY                  7994
# STATE                33601
# ZIP                  16375
# INQ_DATE             30672
# FIRST_INQ_SRCE          34
# CAMPAIGN            166358
# dtype: int64

# %%
nan_rows = AF4[AF4['ID_CONTACT'].isnull()]

# %%
nan_rows
# Out:
#        ID_CONTACT  ID_COMN_APP  ID_APPL  EMPLID EMAIL NOTIF_PLN OPP_RECORD  \
# 97676         NaN          NaN      NaN     NaN   NaN       NaN        NaN
# 97677         NaN          NaN      NaN     NaN   NaN       NaN        NaN
# 345368        NaN          NaN      NaN     NaN   NaN       NaN        NaN
# 345369        NaN          NaN      NaN     NaN   NaN       NaN        NaN
#
#        SCHOOL RECRUIT INIT_RECRUIT_PLN   ...    ADMT_TYPE INQ FNAME  LNAME  \
# 97676     NaN     NaN              NaN   ...          NaN NaN   NaN    NaN
# 97677     NaN     NaN              NaN   ...          NaN NaN   NaN    NaN
# 345368    NaN     NaN              NaN   ...          NaN NaN   NaN    NaN
# 345369    NaN     NaN              NaN   ...          NaN NaN   NaN    NaN
#
#        CITY STATE  ZIP INQ_DATE FIRST_INQ_SRCE CAMPAIGN
# 97676   NaN   NaN  NaN      NaT            NaN      NaN
# 97677   NaN   NaN  NaN      NaT            NaN      NaN
# ...

# %%
AF4.drop(AF4.index[97676])
# Out:
#                                                ID_CONTACT  ID_COMN_APP  \
# 0                                      0031500001eJmOrAAK   19092179.0
# 1                                      0031500001pqNJCAA2   15769046.0
# 2                                      0031500001rQaOMAA0   16921934.0
# 3                                      0031500001rSD9AAAW   17405031.0
# 4                                      0031500001dQ5xrAAC   15950268.0
# 5                                      0031500001dL2rYAAS   15026081.0
# 6                                      0031500001dPY1NAAW   14079292.0
# 7                                      0031500001dLDU3AAO   14114030.0
# 8                                      0031500001dL5vpAAC   14612821.0
# 9                                      0031500001dLJTpAAO   14325041.0
# 10                                     0031500001dLHNxAAO   14395828.0
# 11                                     0031500001dLIuqAAG   14061831.0
# ...

# %%
nan_rows = AF4[AF4['ID_CONTACT'].isnull()]
nan_rows
# Out:
#        ID_CONTACT  ID_COMN_APP  ID_APPL  EMPLID EMAIL NOTIF_PLN OPP_RECORD  \
# 97676         NaN          NaN      NaN     NaN   NaN       NaN        NaN
# 97677         NaN          NaN      NaN     NaN   NaN       NaN        NaN
# 345368        NaN          NaN      NaN     NaN   NaN       NaN        NaN
# 345369        NaN          NaN      NaN     NaN   NaN       NaN        NaN
#
#        SCHOOL RECRUIT INIT_RECRUIT_PLN   ...    ADMT_TYPE INQ FNAME  LNAME  \
# 97676     NaN     NaN              NaN   ...          NaN NaN   NaN    NaN
# 97677     NaN     NaN              NaN   ...          NaN NaN   NaN    NaN
# 345368    NaN     NaN              NaN   ...          NaN NaN   NaN    NaN
# 345369    NaN     NaN              NaN   ...          NaN NaN   NaN    NaN
#
#        CITY STATE  ZIP INQ_DATE FIRST_INQ_SRCE CAMPAIGN
# 97676   NaN   NaN  NaN      NaT            NaN      NaN
# 97677   NaN   NaN  NaN      NaT            NaN      NaN
# ...

# %%
AF8 = AF4.drop(AF4.index[[97676,97677]])

# %%
nan_rows = AF8[AF8['ID_CONTACT'].isnull()]
nan_rows
# Out:
#        ID_CONTACT  ID_COMN_APP  ID_APPL  EMPLID EMAIL NOTIF_PLN OPP_RECORD  \
# 345368        NaN          NaN      NaN     NaN   NaN       NaN        NaN
# 345369        NaN          NaN      NaN     NaN   NaN       NaN        NaN
#
#        SCHOOL RECRUIT INIT_RECRUIT_PLN   ...    ADMT_TYPE INQ FNAME  LNAME  \
# 345368    NaN     NaN              NaN   ...          NaN NaN   NaN    NaN
# 345369    NaN     NaN              NaN   ...          NaN NaN   NaN    NaN
#
#        CITY STATE  ZIP INQ_DATE FIRST_INQ_SRCE CAMPAIGN
# 345368  NaN   NaN  NaN      NaT            NaN      NaN
# 345369  NaN   NaN  NaN      NaT            NaN      NaN
#
# [2 rows x 22 columns]

# %%
AF9 = AF8.drop(AF8.index[345368])
nan_rows = AF9[AF9['ID_CONTACT'].isnull()]
nan_rows
# Out:
#        ID_CONTACT  ID_COMN_APP  ID_APPL  EMPLID EMAIL NOTIF_PLN OPP_RECORD  \
# 97677         NaN          NaN      NaN     NaN   NaN       NaN        NaN
# 345368        NaN          NaN      NaN     NaN   NaN       NaN        NaN
# 345369        NaN          NaN      NaN     NaN   NaN       NaN        NaN
#
#        SCHOOL RECRUIT INIT_RECRUIT_PLN   ...    ADMT_TYPE INQ FNAME  LNAME  \
# 97677     NaN     NaN              NaN   ...          NaN NaN   NaN    NaN
# 345368    NaN     NaN              NaN   ...          NaN NaN   NaN    NaN
# 345369    NaN     NaN              NaN   ...          NaN NaN   NaN    NaN
#
#        CITY STATE  ZIP INQ_DATE FIRST_INQ_SRCE CAMPAIGN
# 97677   NaN   NaN  NaN      NaT            NaN      NaN
# 345368  NaN   NaN  NaN      NaT            NaN      NaN
# 345369  NaN   NaN  NaN      NaT            NaN      NaN
#
# [3 rows x 22 columns]

# %%
nan_rows = AF8[AF8['ID_CONTACT'].isnull()]
nan_rows
#AF8 has 1 nan row removed
# Out:
#        ID_CONTACT  ID_COMN_APP  ID_APPL  EMPLID EMAIL NOTIF_PLN OPP_RECORD  \
# 97677         NaN          NaN      NaN     NaN   NaN       NaN        NaN
# 345368        NaN          NaN      NaN     NaN   NaN       NaN        NaN
# 345369        NaN          NaN      NaN     NaN   NaN       NaN        NaN
#
#        SCHOOL RECRUIT INIT_RECRUIT_PLN   ...    ADMT_TYPE INQ FNAME  LNAME  \
# 97677     NaN     NaN              NaN   ...          NaN NaN   NaN    NaN
# 345368    NaN     NaN              NaN   ...          NaN NaN   NaN    NaN
# 345369    NaN     NaN              NaN   ...          NaN NaN   NaN    NaN
#
#        CITY STATE  ZIP INQ_DATE FIRST_INQ_SRCE CAMPAIGN
# 97677   NaN   NaN  NaN      NaT            NaN      NaN
# 345368  NaN   NaN  NaN      NaT            NaN      NaN
# 345369  NaN   NaN  NaN      NaT            NaN      NaN
#
# [3 rows x 22 columns]

# %%
AF9 = AF8.drop(AF8.index[97677])

# %%
nan_rows2 = AF9[AF9['ID_CONTACT'].isnull()]
nan_rows2
# Out:
#        ID_CONTACT  ID_COMN_APP  ID_APPL  EMPLID EMAIL NOTIF_PLN OPP_RECORD  \
# 97677         NaN          NaN      NaN     NaN   NaN       NaN        NaN
# 345368        NaN          NaN      NaN     NaN   NaN       NaN        NaN
# 345369        NaN          NaN      NaN     NaN   NaN       NaN        NaN
#
#        SCHOOL RECRUIT INIT_RECRUIT_PLN   ...    ADMT_TYPE INQ FNAME  LNAME  \
# 97677     NaN     NaN              NaN   ...          NaN NaN   NaN    NaN
# 345368    NaN     NaN              NaN   ...          NaN NaN   NaN    NaN
# 345369    NaN     NaN              NaN   ...          NaN NaN   NaN    NaN
#
#        CITY STATE  ZIP INQ_DATE FIRST_INQ_SRCE CAMPAIGN
# 97677   NaN   NaN  NaN      NaT            NaN      NaN
# 345368  NaN   NaN  NaN      NaT            NaN      NaN
# 345369  NaN   NaN  NaN      NaT            NaN      NaN
#
# [3 rows x 22 columns]

# %%
AF4.sort_values('ID_CONTACT', inplace = True)

# %%
AF4.head()
# Out:
#                 ID_CONTACT  ID_COMN_APP  ID_APPL  EMPLID  \
# 228547  0031500001d4Si8AAE          NaN      NaN     NaN
# 220307  0031500001d4Si9AAE          NaN      NaN     NaN
# 223208  0031500001d4Si9AAE          NaN      NaN     NaN
# 181935  0031500001d4SiAAAU          NaN      NaN     NaN
# 237097  0031500001d4SiBAAU          NaN      NaN     NaN
#
#                                   EMAIL NOTIF_PLN     OPP_RECORD  \
# 228547           aleama.rocky@gmail.com       NaN  UGrad Inquiry
# 220307        gabriela.pons@hotmail.com       NaN  UGrad Inquiry
# 223208        gabriela.pons@hotmail.com       NaN  UGrad Inquiry
# 181935  ehrlich.christopher00@gmail.com       NaN  UGrad Inquiry
# 237097             jaibrown99@yahoo.com       NaN  UGrad Inquiry
#
#                                     SCHOOL  \
# 228547        College of Arts and Sciences
# 220307  School of Nursing & Health Studies
# 223208        College of Arts and Sciences
# 181935   School of Business Administration
# ...

# %%
nan_rows3 = AF4[AF4['ID_CONTACT'].isnull()]
nan_rows3
# Out:
#        ID_CONTACT  ID_COMN_APP  ID_APPL  EMPLID EMAIL NOTIF_PLN OPP_RECORD  \
# 97676         NaN          NaN      NaN     NaN   NaN       NaN        NaN
# 97677         NaN          NaN      NaN     NaN   NaN       NaN        NaN
# 345368        NaN          NaN      NaN     NaN   NaN       NaN        NaN
# 345369        NaN          NaN      NaN     NaN   NaN       NaN        NaN
#
#        SCHOOL RECRUIT INIT_RECRUIT_PLN   ...    ADMT_TYPE INQ FNAME  LNAME  \
# 97676     NaN     NaN              NaN   ...          NaN NaN   NaN    NaN
# 97677     NaN     NaN              NaN   ...          NaN NaN   NaN    NaN
# 345368    NaN     NaN              NaN   ...          NaN NaN   NaN    NaN
# 345369    NaN     NaN              NaN   ...          NaN NaN   NaN    NaN
#
#        CITY STATE  ZIP INQ_DATE FIRST_INQ_SRCE CAMPAIGN
# 97676   NaN   NaN  NaN      NaT            NaN      NaN
# 97677   NaN   NaN  NaN      NaT            NaN      NaN
# ...

# %%
 AF4.drop(AF4.index[[97676,97677]], inplace =True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-83-b3f2b97c08d4> in <module>()
# ----> 1 AF4.drop(AF4.index[[97676,97677]], inplace =True)
#
# AttributeError: 'NoneType' object has no attribute 'drop'

# %%
nan_rows = AF4[AF4['ID_CONTACT'].isnull()]
nan_rows
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-edc2bbbeac2a> in <module>()
# ----> 1 nan_rows = AF4[AF4['ID_CONTACT'].isnull()]
#       2 nan_rows
#
# TypeError: 'NoneType' object is not subscriptable

# %%
AF4.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-84-df3d7111c736> in <module>()
# ----> 1 AF4.head()
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
F1 = AF3.rename(columns ={'Contact ID (18-digit)': 'ID_CONTACT', 'Common App ID': 'ID_COMN_APP', 'Application Number': 'ID_APPL',
       'Empl ID': 'EMPLID', 'Email': 'EMAIL', 'Notification Plan': 'NOTIF_PLN', 'Opportunity Record Type': 'OPP_RECORD',
       'School / College':'SCHOOL', 'Recruitment Program': 'RECRUIT', 'Initial Recruitment Plan':'INIT_RECRUIT_PLN',
       'Academic Plan: Plan Type':'ACAD_PLN', 'Term: Term Name':'TERM', 'Admit Type':"ADMT_TYPE", 'Inquiry':'INQ',
       'First Name':'FNAME', 'Last Name':'LNAME', 'Mailing City':'CITY', 'Mailing State/Province':'STATE',
       'Mailing Zip/Postal Code':'ZIP', 'Inquiry Date':'INQ_DATE', 'First Inquiry Source':'FIRST_INQ_SRCE',
       'Primary Campaign Source: Campaign Name':'CAMPAIGN'})

# %%
F1.head()
# Out:
#            ID_CONTACT  ID_COMN_APP   ID_APPL      EMPLID  \
# 0  0031500001eJmOrAAK   19092179.0  350719.0  54311370.0
# 1  0031500001pqNJCAA2   15769046.0  279998.0  54238140.0
# 2  0031500001rQaOMAA0   16921934.0  292329.0  54251168.0
# 3  0031500001rSD9AAAW   17405031.0  293286.0  54249230.0
# 4  0031500001dQ5xrAAC   15950268.0  284830.0  54242433.0
#
#                                 EMAIL NOTIF_PLN       OPP_RECORD  \
# 0             williamsa4321@gmail.com       REG  UGrad Applicant
# 1               ebraun12321@gmail.com       REG  UGrad Applicant
# 2       ambiance.alirezai99@gmail.com       REG  UGrad Applicant
# 3           edward.ke.lin@foxmail.com       REG  UGrad Applicant
# 4  pierre.jones.17@wheels-student.org       REG  UGrad Applicant
#
#                          SCHOOL                        RECRUIT  \
# 0       School of Communication  Communication - Undergraduate
# 1  College of Arts and Sciences   Theatre Arts - Undergraduate
# ...

# %%
F1.isnull().sum()
# Out:
# ID_CONTACT               4
# ID_COMN_APP         278881
# ID_APPL             278284
# EMPLID              274782
# EMAIL                 3112
# NOTIF_PLN           278552
# OPP_RECORD              14
# SCHOOL                 390
# RECRUIT                390
# INIT_RECRUIT_PLN       321
# ACAD_PLN            278279
# TERM                    14
# ADMT_TYPE               14
# INQ                     14
# FNAME                   16
# LNAME                   14
# CITY                  7994
# STATE                33601
# ZIP                  16375
# INQ_DATE             30672
# FIRST_INQ_SRCE          34
# CAMPAIGN            166358
# dtype: int64

# %%
F1.isna().sum()
# Out:
# ID_CONTACT               4
# ID_COMN_APP         278881
# ID_APPL             278284
# EMPLID              274782
# EMAIL                 3112
# NOTIF_PLN           278552
# OPP_RECORD              14
# SCHOOL                 390
# RECRUIT                390
# INIT_RECRUIT_PLN       321
# ACAD_PLN            278279
# TERM                    14
# ADMT_TYPE               14
# INQ                     14
# FNAME                   16
# LNAME                   14
# CITY                  7994
# STATE                33601
# ZIP                  16375
# INQ_DATE             30672
# FIRST_INQ_SRCE          34
# CAMPAIGN            166358
# dtype: int64

# %%
F1['ID_CONTACT'].dtype
# Out:
# dtype('O')

# %%
#dtype('O')  is a string
F1.dtypes
# Out:
# ID_CONTACT                  object
# ID_COMN_APP                float64
# ID_APPL                    float64
# EMPLID                     float64
# EMAIL                       object
# NOTIF_PLN                   object
# OPP_RECORD                  object
# SCHOOL                      object
# RECRUIT                     object
# INIT_RECRUIT_PLN            object
# ACAD_PLN                    object
# TERM                        object
# ADMT_TYPE                   object
# INQ                        float64
# FNAME                       object
# LNAME                       object
# CITY                        object
# STATE                       object
# ZIP                         object
# INQ_DATE            datetime64[ns]
# FIRST_INQ_SRCE              object
# CAMPAIGN                    object
# dtype: object

# %%
F1[F1['ID_CONTACT'].notnull()]
# Out:
#                                                ID_CONTACT  ID_COMN_APP  \
# 0                                      0031500001eJmOrAAK   19092179.0
# 1                                      0031500001pqNJCAA2   15769046.0
# 2                                      0031500001rQaOMAA0   16921934.0
# 3                                      0031500001rSD9AAAW   17405031.0
# 4                                      0031500001dQ5xrAAC   15950268.0
# 5                                      0031500001dL2rYAAS   15026081.0
# 6                                      0031500001dPY1NAAW   14079292.0
# 7                                      0031500001dLDU3AAO   14114030.0
# 8                                      0031500001dL5vpAAC   14612821.0
# 9                                      0031500001dLJTpAAO   14325041.0
# 10                                     0031500001dLHNxAAO   14395828.0
# 11                                     0031500001dLIuqAAG   14061831.0
# ...

# %%
F1.count()
# Out:
# ID_CONTACT          443054
# ID_COMN_APP         164177
# ID_APPL             164774
# EMPLID              168276
# EMAIL               439946
# NOTIF_PLN           164506
# OPP_RECORD          443044
# SCHOOL              442668
# RECRUIT             442668
# INIT_RECRUIT_PLN    442737
# ACAD_PLN            164779
# TERM                443044
# ADMT_TYPE           443044
# INQ                 443044
# FNAME               443042
# LNAME               443044
# CITY                435064
# STATE               409457
# ZIP                 426683
# INQ_DATE            412386
# FIRST_INQ_SRCE      443024
# CAMPAIGN            276700
# dtype: int64

# %%
F1.isna().sum()
# Out:
# ID_CONTACT               4
# ID_COMN_APP         278881
# ID_APPL             278284
# EMPLID              274782
# EMAIL                 3112
# NOTIF_PLN           278552
# OPP_RECORD              14
# SCHOOL                 390
# RECRUIT                390
# INIT_RECRUIT_PLN       321
# ACAD_PLN            278279
# TERM                    14
# ADMT_TYPE               14
# INQ                     14
# FNAME                   16
# LNAME                   14
# CITY                  7994
# STATE                33601
# ZIP                  16375
# INQ_DATE             30672
# FIRST_INQ_SRCE          34
# CAMPAIGN            166358
# dtype: int64

# %%
F1.dropna(subset = ['ID_CONTACT'],how = 'all', inplace = True)

# %%
F1.count()
# Out:
# ID_CONTACT          443054
# ID_COMN_APP         164177
# ID_APPL             164774
# EMPLID              168276
# EMAIL               439946
# NOTIF_PLN           164506
# OPP_RECORD          443044
# SCHOOL              442668
# RECRUIT             442668
# INIT_RECRUIT_PLN    442737
# ACAD_PLN            164779
# TERM                443044
# ADMT_TYPE           443044
# INQ                 443044
# FNAME               443042
# LNAME               443044
# CITY                435064
# STATE               409457
# ZIP                 426683
# INQ_DATE            412386
# FIRST_INQ_SRCE      443024
# CAMPAIGN            276700
# dtype: int64

# %%
F1.fillna(value = 0, inplace = True)
#this put a 0 anywhere there was a NaN

# %%
F1[F1['ID_CONTACT'] != 0]
# Out:
#                                                ID_CONTACT  ID_COMN_APP  \
# 0                                      0031500001eJmOrAAK   19092179.0
# 1                                      0031500001pqNJCAA2   15769046.0
# 2                                      0031500001rQaOMAA0   16921934.0
# 3                                      0031500001rSD9AAAW   17405031.0
# 4                                      0031500001dQ5xrAAC   15950268.0
# 5                                      0031500001dL2rYAAS   15026081.0
# 6                                      0031500001dPY1NAAW   14079292.0
# 7                                      0031500001dLDU3AAO   14114030.0
# 8                                      0031500001dL5vpAAC   14612821.0
# 9                                      0031500001dLJTpAAO   14325041.0
# 10                                     0031500001dLHNxAAO   14395828.0
# 11                                     0031500001dLIuqAAG   14061831.0
# ...

# %%
F1.count()
# Out:
# ID_CONTACT          443054
# ID_COMN_APP         443054
# ID_APPL             443054
# EMPLID              443054
# EMAIL               443054
# NOTIF_PLN           443054
# OPP_RECORD          443054
# SCHOOL              443054
# RECRUIT             443054
# INIT_RECRUIT_PLN    443054
# ACAD_PLN            443054
# TERM                443054
# ADMT_TYPE           443054
# INQ                 443054
# FNAME               443054
# LNAME               443054
# CITY                443054
# STATE               443054
# ZIP                 443054
# INQ_DATE            443054
# FIRST_INQ_SRCE      443054
# CAMPAIGN            443054
# dtype: int64

# %%
Affinity = AF3.rename(columns ={'Contact ID (18-digit)': 'ID_CONTACT', 'Common App ID': 'ID_COMN_APP', 'Application Number': 'ID_APPL',
       'Empl ID': 'EMPLID', 'Email': 'EMAIL', 'Notification Plan': 'NOTIF_PLN', 'Opportunity Record Type': 'OPP_RECORD',
       'School / College':'SCHOOL', 'Recruitment Program': 'RECRUIT', 'Initial Recruitment Plan':'INIT_RECRUIT_PLN',
       'Academic Plan: Plan Type':'ACAD_PLN', 'Term: Term Name':'TERM', 'Admit Type':"ADMT_TYPE", 'Inquiry':'INQ',
       'First Name':'FNAME', 'Last Name':'LNAME', 'Mailing City':'CITY', 'Mailing State/Province':'STATE',
       'Mailing Zip/Postal Code':'ZIP', 'Inquiry Date':'INQ_DATE', 'First Inquiry Source':'FIRST_INQ_SRCE',
       'Primary Campaign Source: Campaign Name':'CAMPAIGN'})

# %%
Affinity.to_excel('Affinity.xlsx')
