# %%
import numpy as np
import pandas as pd

# %%
from scipy import stats,integrate
import matplotlib.pyplot as plt

# %%
 import seaborn as sns
 sns.set (color_codes=True)

# %%
 new=pd.read_excel('C:/Users/mjc341/desktop/TESTPY/NEW_MKT.xlsx')

# %%
new.head()
# Out:
#    Total-New Family_Income_Cat
# 0        0.0     Not Available
# 1     6500.0        below $80K
# 2     5387.0       above $120K
# 3    69577.0     Not Available
# 4    50314.0       above $120K

# %%
sns.stripplot(x='Total-New', y= 'Family_Income_Cat', data=new,jitter =True);

# %%
plt.show()

# %%
sns.stripplot(x='Family_Income_Cat', y= 'Total-New', data=new,jitter =True);

# %%
plt.show()

# %%
sns.swarmplot(x='Family_Income_Cat', y= 'Total-New', data=new);

# %%
contin=pd.read_excel('C:/Users/mjc341/desktop/TESTPY/CONTIN_MKT.xlsx')

# %%
contin.head()
# Out:
#    Total-Contin   Family_Income_Cat
# 0           0.0       Not Available
# 1       29800.0         above $120K
# 2       36500.0          below $80K
# 3       46775.0         above $120K
# 4       36900.0  between $80k-$120K

# %%
sns.stripplot(x='Family_Income_Cat', y= 'Total-Contin', data=contin,jitter =True);

# %%
plt.show()

# %%
sns.stripplot(x='Family_Income_Cat', y= 'Total-Contin', data=contin,jitter =True);

# %%
plt.show()

# %%
 new2=pd.read_excel('C:/Users/mjc341/desktop/TESTPY/NEW_MKT2.xlsx')

# %%
new2.head()
# Out:
#    Total-new Family_Income_Cat
# 0     6500.0        below $80K
# 1     5387.0       above $120K
# 2    50314.0       above $120K
# 3    30000.0        below $80K
# 4    46692.0        below $80K

# %%
sns.stripplot(x='Family_Income_Cat', y= 'Total-new', data=new2,jitter =True);

# %%
plt.rcParams['figure.figsize']=(8,10)

# %%
plt.show()
