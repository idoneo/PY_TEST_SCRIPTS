# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob

# %%
path = r'C:/Users/mjc341/Desktop/FER Downloads/Export'
path_final = r'C:Users/mjc341/Desktop/FER Downloads/Export/Final'
files = glob.glob (path + "/Export_Job1_*_06-02.csv")

# %%
files
# Out:
# ['C:/Users/mjc341/Desktop/FER Downloads/Export\\Export_Job1_01-05-2018_06-02.csv',
#  'C:/Users/mjc341/Desktop/FER Downloads/Export\\Export_Job1_01-12-2018_06-02.csv',
#  'C:/Users/mjc341/Desktop/FER Downloads/Export\\Export_Job1_01-19-2018_06-02.csv',
#  'C:/Users/mjc341/Desktop/FER Downloads/Export\\Export_Job1_01-26-2018_06-02.csv',
#  'C:/Users/mjc341/Desktop/FER Downloads/Export\\Export_Job1_02-02-2018_06-02.csv',
#  'C:/Users/mjc341/Desktop/FER Downloads/Export\\Export_Job1_02-09-2018_06-02.csv',
#  'C:/Users/mjc341/Desktop/FER Downloads/Export\\Export_Job1_02-16-2018_06-02.csv',
#  'C:/Users/mjc341/Desktop/FER Downloads/Export\\Export_Job1_02-23-2018_06-02.csv',
#  'C:/Users/mjc341/Desktop/FER Downloads/Export\\Export_Job1_03-02-2018_06-02.csv',
#  'C:/Users/mjc341/Desktop/FER Downloads/Export\\Export_Job1_03-09-2018_06-02.csv',
#  'C:/Users/mjc341/Desktop/FER Downloads/Export\\Export_Job1_03-16-2018_06-02.csv',
# ...

# %%
len(files)
# Out:
# 24

# %%
files2 = glob.glob (path + "/Export_Job1_*_23-48.csv")

# %%
files2
# Out:
# ['C:/Users/mjc341/Desktop/FER Downloads/Export\\Export_Job1_03-11-2018_23-48.csv']

# %%
files.append(files2)

# %%
len(files)
# Out:
# 25

# %%
FER_RESP_COUNT2 =[]

# %%
import csv
input = 'C:/Users/mjc341/Desktop/FER Downloads/Export\Export_Job1_02-16-2018_06-02.csv'
with open(input ,"r") as f:
        reader = csv.reader(f,delimiter = ",")
        data = list(reader)
        row_count = len(data)-1
        print(row_count)
# Out:
# 843

# %%
FER_RESP_COUNT2.append(row_count)

# %%
FER_RESP_COUNT2
# Out:
# [189, 78, 473, 5386, 792, 1368, 1368, 843]

# %%
for i in files:
    print (i)
# Out:
# C:/Users/mjc341/Desktop/FER Downloads/Export\Export_Job1_01-05-2018_06-02.csv
# C:/Users/mjc341/Desktop/FER Downloads/Export\Export_Job1_01-12-2018_06-02.csv
# C:/Users/mjc341/Desktop/FER Downloads/Export\Export_Job1_01-19-2018_06-02.csv
# C:/Users/mjc341/Desktop/FER Downloads/Export\Export_Job1_01-26-2018_06-02.csv
# C:/Users/mjc341/Desktop/FER Downloads/Export\Export_Job1_02-02-2018_06-02.csv
# C:/Users/mjc341/Desktop/FER Downloads/Export\Export_Job1_02-09-2018_06-02.csv
# C:/Users/mjc341/Desktop/FER Downloads/Export\Export_Job1_02-16-2018_06-02.csv
# C:/Users/mjc341/Desktop/FER Downloads/Export\Export_Job1_02-23-2018_06-02.csv
# C:/Users/mjc341/Desktop/FER Downloads/Export\Export_Job1_03-02-2018_06-02.csv
# C:/Users/mjc341/Desktop/FER Downloads/Export\Export_Job1_03-09-2018_06-02.csv
# C:/Users/mjc341/Desktop/FER Downloads/Export\Export_Job1_03-16-2018_06-02.csv
# C:/Users/mjc341/Desktop/FER Downloads/Export\Export_Job1_03-23-2018_06-02.csv
# ...

# %%
"""input = 
for i in file:
    print (i)
with open(input ,"r") as f:
        reader = csv.reader(f,delimiter = ",")
        data = list(reader)
        row_count = len(data)-1
        print(row_count)"""

# %%
"""for filename in glob.glob(path + "/Export_Job1_*_06-02.csv"):
    data = pd.read_csv(filename)
print(filename, data['Last_Name'].count())"""
# Out:
# 'for filename in glob.glob(path + "/Export_Job1_*_06-02.csv"):\n    data = pd.read_csv(filename)\nprint(filename, data[\'Last_Name\'].count())'

# %%
FER_COUNT = []
for i in files:
    with open(i,"r") as f:
        reader = csv.reader(f,delimiter = ",")
        data = list(reader)
        row_count = len(data)-1
        print(row_count)
# Out:
# 189
# 78
# 473
# 5386
# 792
# 1368
# 843
# 372
# 829
# 151
# 589
# 353
# 384
# 75
# 373
# 77
# 528
# 622
# 315
# 51
# 32
# 1019
# 301
# 43
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-86-c19a0228e811> in <module>()
#       1 FER_COUNT = []
#       2 for i in files:
# ----> 3     with open(i,"r") as f:
#       4         reader = csv.reader(f,delimiter = ",")
#       5         data = list(reader)
#
# TypeError: expected str, bytes or os.PathLike object, not list

# %%
FER_COUNTS=[189,78,473,5386,792,1368,843,372,829,151,589,353,384,75,373,77,528,622,315,51,32,
1019,301,43,105,]

# %%
sum_FER=(sum(FER_COUNTS))

# %%
print(sum_FER)
# Out:
# 15348

# %%
path = r'C:/Users/mjc341/Desktop/FER Downloads/Export'
path_final = r'C:Users/mjc341/Desktop/FER Downloads/Export/Final'
filenames = glob.glob (path + "/Export_Job1_*_06-02.csv")

# %%
CSV_FILES = []

# %%
for filename in filenames:
    CSV_FILES.append(pd.read_csv(filename,skiprows =1, engine='python',index_col =False))

# %%
CSV_FILES
# Out:
# [     New      Anisa    C        Clark                  acc1819@hotmail.com  \
#  0    New      Corey    L      Collins             coreycollins02@gmail.com
#  1    New     Brekel  NaN        Tibbs                brekeltibbs@gmail.com
#  2    New       Reid    B      Dobbins                reiddobbins@gmail.com
#  3    New    Nicolas    T      Pacheco            nicolastpacheco@gmail.com
#  4    New        Ian    R      Guilday                  iguilday1@gmail.com
#  5    New   Courtney    A       Curtis       superreader01.curtis@gmail.com
#  6    New    Jocelyn  NaN           Ye               jocelynye423@yahoo.com
#  7    New      Laith  NaN        Kewan                   cdkewan@icloud.com
#  8    New  Nwadinobi    O   Onyeagocha                  pharmwizz@gmail.com
#  9    New     Declan    R      Carroll            declancarrollsc@gmail.com
#  10   New     Olivia    N       Slavov               oliviaslavov@gmail.com
# ...

# %%
for i in filenames:
    with open(i,"r") as f:
        reader = csv.reader(f,delimiter = ",")
        data = list(reader)
        row_count = len(data)-1
        print(i,row_count)
# Out:
# C:/Users/mjc341/Desktop/FER Downloads/Export\Export_Job1_01-05-2018_06-02.csv 189
# C:/Users/mjc341/Desktop/FER Downloads/Export\Export_Job1_01-12-2018_06-02.csv 78
# C:/Users/mjc341/Desktop/FER Downloads/Export\Export_Job1_01-19-2018_06-02.csv 473
# C:/Users/mjc341/Desktop/FER Downloads/Export\Export_Job1_01-26-2018_06-02.csv 5386
# C:/Users/mjc341/Desktop/FER Downloads/Export\Export_Job1_02-02-2018_06-02.csv 792
# C:/Users/mjc341/Desktop/FER Downloads/Export\Export_Job1_02-09-2018_06-02.csv 1368
# C:/Users/mjc341/Desktop/FER Downloads/Export\Export_Job1_02-16-2018_06-02.csv 843
# C:/Users/mjc341/Desktop/FER Downloads/Export\Export_Job1_02-23-2018_06-02.csv 372
# C:/Users/mjc341/Desktop/FER Downloads/Export\Export_Job1_03-02-2018_06-02.csv 829
# C:/Users/mjc341/Desktop/FER Downloads/Export\Export_Job1_03-09-2018_06-02.csv 151
# C:/Users/mjc341/Desktop/FER Downloads/Export\Export_Job1_03-16-2018_06-02.csv 589
# ...

# %%
for i in filenames:
    with open(i,"r") as f:
        reader = csv.reader(f,delimiter = ",")
        data = list(reader)
        row_count = len(data)-1
        print(row_count)
# Out:
# 189
# 78
# 473
# 5386
# 792
# 1368
# 843
# 372
# 829
# 151
# 589
# 353
# 384
# 75
# 373
# 77
# 528
# 622
# 315
# 51
# 32
# 1019
# 301
# 43

# %%
List_COUNT = []
for i in filenames:
    with open(i,"r") as f:
        reader = csv.reader(f,delimiter = ",")
        data = list(reader)
        row_count = len(data)-1
        List_COUNT.append(row_count)

# %%
List_COUNT
# Out:
# [189,
#  78,
#  473,
#  5386,
#  792,
#  1368,
#  843,
#  372,
#  829,
#  151,
#  589,
#  353,
#  384,
#  75,
#  373,
#  77,
#  528,
#  622,
#  315,
#  51,
#  32,
#  1019,
#  301,
#  43]

# %%
sum_FER2=(sum(List_COUNT))

# %%
print(sum_FER2)
# Out:
# 15243

# %%
for i in filenames:
    with open(i,"r") as f:
        reader = csv.reader(f,dialect='excel',delimiter = ",")
        data = list(reader)
        row_count = len(data)-1
        print(i,row_count)
# Out:
# C:/Users/mjc341/Desktop/FER Downloads/Export\Export_Job1_01-05-2018_06-02.csv 189
# C:/Users/mjc341/Desktop/FER Downloads/Export\Export_Job1_01-12-2018_06-02.csv 78
# C:/Users/mjc341/Desktop/FER Downloads/Export\Export_Job1_01-19-2018_06-02.csv 473
# C:/Users/mjc341/Desktop/FER Downloads/Export\Export_Job1_01-26-2018_06-02.csv 5386
# C:/Users/mjc341/Desktop/FER Downloads/Export\Export_Job1_02-02-2018_06-02.csv 792
# C:/Users/mjc341/Desktop/FER Downloads/Export\Export_Job1_02-09-2018_06-02.csv 1368
# C:/Users/mjc341/Desktop/FER Downloads/Export\Export_Job1_02-16-2018_06-02.csv 843
# C:/Users/mjc341/Desktop/FER Downloads/Export\Export_Job1_02-23-2018_06-02.csv 372
# C:/Users/mjc341/Desktop/FER Downloads/Export\Export_Job1_03-02-2018_06-02.csv 829
# C:/Users/mjc341/Desktop/FER Downloads/Export\Export_Job1_03-09-2018_06-02.csv 151
# C:/Users/mjc341/Desktop/FER Downloads/Export\Export_Job1_03-16-2018_06-02.csv 589
# ...

# %%
path = path = r'C:/Users/mjc341/Desktop/FER Downloads/Export'
path_final = r'C:Users/mjc341/Desktop/FER Downloads/Export/Final'
filenames3 = glob.glob (path + "/Export_Job1_*_06-02.csv")
filenames4 =glob.glob (path + "/Export_Job1_*_23-48.csv")

# %%
RAW_FER = []

# %%
for filename in filenames3:
    RAW_FER.append(pd.read_csv(filename, skiprows=1,  engine='python', index_col=False))
for filename in filenames4:
    RAW_FER.append(pd.read_csv(filename, skiprows=1,  engine='python', index_col=False))

# %%
RAW_FER_df = pd.concat(RAW_FER, ignore_index =True)

# %%
len(RAW_FER_df)
# Out:
# 45994

# %%
for filename in filenames3:
    RAW_FER.append(pd.read_csv(filename, skiprows=0,  engine='python', index_col=False))
for filename in filenames4:
    RAW_FER.append(pd.read_csv(filename, skiprows=0,  engine='python', index_col=False))  
    RAW_FER_df2 = pd.concat(RAW_FER, ignore_index =True)

# %%
  len(RAW_FER_df2)/3
# Out:
# 30679.333333333332

# %%
RF = [ ]

# %%
#here I used Pandas which automatically accountd for header rows
for filename in filenames3:
    RF.append(pd.read_csv(filename, skiprows=0,  engine='python', index_col=False))
for filename in filenames4:
    RF.append(pd.read_csv(filename, skiprows=0,  engine='python', index_col=False))  
    RF2 = pd.concat(RF, ignore_index =True)

# %%
len(RF)
#25 files are in the list generated by glob actually 24+1
# Out:
# 25

# %%
len(RF2) #turn the list of file names into a df of all the contents, then count the rows
# Out:
# 15348

# %%
RF2.head(2)
# Out:
#   Interaction_Status__c First_Name__c Middle_Name__c Last_Name__c  \
# 0                   New         Anisa              C        Clark
# 1                   New         Corey              L      Collins
#
#                    Email__c Birthdate__c Gender__c            Ethnicity__c  \
# 0       acc1819@hotmail.com   05/19/2002    Female  Black/African American
# 1  coreycollins02@gmail.com   03/20/2002      Male  Black/African American
#
#   Mailing_Street__c Mailing_Street2__c       ...         CEEB_Code__c  \
# 0     613 Medway Dr                NaN       ...               112043
# 1       Po Box 3026                NaN       ...               112866
#
#   GMAT_Score_Range__c Graduation_Year__c GMAT_Years_of_Work_Experience__c  \
# 0                 NaN               2020                              NaN
# 1                 NaN               2020                              NaN
#
#   How_did_you_hear_about_our_programs__c  GMAT_Age_Range__c  \
# ...

# %%
RF2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15348 entries, 0 to 15347
# Data columns (total 36 columns):
# Interaction_Status__c                     15348 non-null object
# First_Name__c                             15348 non-null object
# Middle_Name__c                            12432 non-null object
# Last_Name__c                              15348 non-null object
# Email__c                                  15346 non-null object
# Birthdate__c                              15348 non-null object
# Gender__c                                 15348 non-null object
# Ethnicity__c                              15233 non-null object
# Mailing_Street__c                         15348 non-null object
# Mailing_Street2__c                        880 non-null object
# Mailing_Street3__c                        0 non-null float64
# Mailing_City__c                           15348 non-null object
# Mailing_State__c                          15345 non-null object
# ...
