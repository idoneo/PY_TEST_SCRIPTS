# %%
import numpy as np
import pandas as pd
from scipy import stats, integrate
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes = True)

# %%
def hello():
    print ("Hello World")
hello ()
# Out:
# Hello World

# %%
tips=sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
g2 = sns.jointplot("total_bill","tip",data=tips, kind="reg", xlim=(0,60),ylim=(0,20), size=7)

# %%
plt.show()

# %%
import numpy as np
import pandas as pd
from scipy import stats, integrate
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes = True)

# %%
dta1 = pd.read_excel('C:/Users/mjc341/desktop/TESTPY/Gateway_Filtered_POP.xlsx')

# %%
dta1.head(5)
# Out:
#          ID Career  Term Acad Group Subject Catalog  Course ID EarnCredit  \
# 0  54146032   UGRD  2168         ED     TAL     103     100733          Y
# 1  54164005   UGRD  2168         BU     MKT     201     115416          Y
# 2  54164048   UGRD  2168         BU     MKT     201     115416          Y
# 3  54186414   UGRD  2168         BU     MKT     201     115416          Y
# 4  54155120   UGRD  2168         BU     MKT     201     115416          Y
#
#   Repeat  Units       ...          COURSE BM Y BM Acad Group      MAJOR  \
# 0    NaN      3       ...        TAL  103    Y            AS    PSYC_AB
# 1    NaN      3       ...        MKT  201    Y            BU  FINL_BSBA
# 2    NaN      3       ...        MKT  201    Y            BU   ECON_BBA
# 3    NaN      3       ...        MKT  201    Y            BU  MGMT_BSBA
# 4    NaN      3       ...        MKT  201    Y            BU  BU_BBA_UN
#
#       Degree_Seek   Admit Type FTE  Pass/FailConversion Pass_FAIL  \
# ...

# %%
dta1.columns
# Out:
# Index(['ID', 'Career', 'Term', 'Acad Group', 'Subject', 'Catalog', 'Course ID',
#        'EarnCredit', 'Repeat', 'Units', 'Status', 'Wdraw Code', 'Section',
#        'Course Car', 'Grade Base', 'Unit Taken', 'Grade', 'Drop Dt',
#        'Prim Prog', 'Descr', 'COURSE', 'BM Y', 'BM Acad Group', 'MAJOR',
#        'Degree_Seek', 'Admit Type', 'FTE', 'Pass/FailConversion', 'Pass_FAIL',
#        'Full Conversion'],
#       dtype='object')

# %%
#change column names
dta1.rename(columns= {'ID':'EMPL_ID', 'Career':'CAREER', 'Term':'TERM', 'Acad Group':'SCHOOL', 'Subject':'SUBJ', 
                      'Catalog':'CAT_NO', 'Course ID':'COURSE_ID','EarnCredit':'CREDIT', 'Repeat':'RPT', 
                      'Units':'UNITS', 'Status':'STAT', 'Wdraw Code':'W', 'Section':'SEC', 'Course Car':'COURSE_CAR', 
                      'Grade Base':'GRADE_BASE', 'Unit Taken':'UNITS', 'Grade':'LETTER_GRADE', 'Drop Dt':'DROPPED',
                      'Prim Prog':'PROG', 'Descr':'DESC', 'COURSE':'COURSE', 'BM Y': 'BM', 'BM Acad Group':'BM_SCHOOL', 
                      'MAJOR': 'BM_MAJOR', 'Degree_Seek':'DEGREE', 'Admit Type':'ADMIT_TYPE', 'FTE':'FTE', 
                      'Pass/FailConversion':'CONVERT_GRADE1','Pass_FAIL':'PASS_FAIL', 'Full Conversion':'CONVERT_GRADE_FULL'})
# Out:
#         EMPL_ID CAREER  TERM SCHOOL SUBJ CAT_NO  COURSE_ID CREDIT  RPT  UNITS  \
# 0      54146032   UGRD  2168     ED  TAL    103     100733      Y  NaN      3
# 1      54164005   UGRD  2168     BU  MKT    201     115416      Y  NaN      3
# 2      54164048   UGRD  2168     BU  MKT    201     115416      Y  NaN      3
# 3      54186414   UGRD  2168     BU  MKT    201     115416      Y  NaN      3
# 4      54155120   UGRD  2168     BU  MKT    201     115416      Y  NaN      3
# 5      50477452   UGRD  2168     AS  WGS    201     113680      Y  NaN      3
# 6      54159385   UGRD  2168     AS  WGS    201     113680      Y  NaN      3
# 7      54164251   UGRD  2168     MU  DAN    111     103298      Y  NaN      2
# 8      54158882   UGRD  2168     AS  ENG    201     105823      Y  NaN      3
# 9      54156751   UGRD  2168     AS  ENG    201     105823      Y  NaN      3
# 10     54158894   UGRD  2168     AS  ENG    201     105823      Y  NaN      3
# ...

# %%
dta1.values
# Out:
# array([[54146032, 'UGRD', 2168, ..., 4.0, 'PASS', 4],
#        [54164005, 'UGRD', 2168, ..., 4.0, 'PASS', 4],
#        [54164048, 'UGRD', 2168, ..., 4.0, 'PASS', 4],
#        ...,
#        [54199992, 'UGRD', 2178, ..., 0.0, 'FAIL', 'W'],
#        [54215770, 'UGRD', 2178, ..., 0.0, 'FAIL', 'W'],
#        [54221330, 'UGRD', 2178, ..., 0.0, 'FAIL', 'W']], dtype=object)
